# %%
#import libraries
import numpy as np
import pandas as pd
import geopandas as gpd
import fiona
import folium
import matplotlib.pyplot as plt

# %%
# Read in# Read in contract  csv file
contract_data = pd.read_csv("../IL_CEI/can-summer-2023/data/raw/contracts/illinois_bidbuy_contracts_as_of_20230614.csv")
# make the company name lower case
contract_data["Vendor"] = contract_data.Vendor.str.lower()
contract_data
# Out:
#          Contract / Blanket #  Bid Solicitation #  \
# 0                  CIB6354390                 NaN
# 1                  CIB5736630                 NaN
# 2     23-563WCC-WCC56-P-39787                 NaN
# 3     23-563WCC-WCC56-P-38456                 NaN
# 4     23-551HDA-LEGAL-P-39047                 NaN
# ...                       ...                 ...
# 1371     17-416CMS-BOSS4-P-99                 NaN
# 1372     17-416CMS-BOSS4-P-39                 NaN
# 1373               14Z0879001                 NaN
# 1374               13Z1819001                 NaN
# 1375               000MY14222                 NaN
#
#                                    Description  \
# 0                           Prescription Drugs
# 1          ConnectYourCare - Flexible Spending
# 2       Sole Source- WCRI CompScope Reports 23
# 3            EDI Hosting and Maintenance FY 23
# 4        Foley & Lardner Bond Counsel (Exempt)
# ...                                        ...
# 1371       JPMC PAPER AND ENVELOPES SMALL QTYS
# 1372               MC Fleet Fuel Card Services
# 1373      Pharmacy Benefits Management (PBMS)
# 1374  HFS MMIS Upgrade Project Expert Services
# 1375   SBE: Student Information System Support
#
#                                            Vendor Type Code  \
# 0                      caremarkpcs health, l.l.c.         B
# 1                            connectyourcare, llc         A
# 2                                            wcri         D
# 3                                      ebix, inc.         C
# 4                             foley & lardner llp         Z
# ...                                           ...       ...
# 1371                                midland paper         A
# 1372                                     wex bank         B
# 1373   change healthcare pharmacy solutions, inc.         B
# 1374       cognizant technology solutions us corp         B
# 1375  international business machines corporation         B
#
#      Dollars Spent to Date                                     Organization  \
# 0                    $0.00                CMS - Central Management Services
# 1                    $0.00                CMS - Central Management Services
# 2                    $0.00  WCC - Illinois Worker's Compensation Commission
# 3                    $0.00  WCC - Illinois Worker's Compensation Commission
# 4                    $0.00              HDA - Housing Development Authority
# ...                    ...                                              ...
# 1371         $4,502,328.93                CMS - Central Management Services
# 1372           $279,800.00                CMS - Central Management Services
# 1373                 $0.00             HFS - Healthcare and Family Services
# 1374                 $0.00             HFS - Healthcare and Family Services
# 1375                 $0.00                   SBE - State Board of Education
#
#           Status  Begin Date    End Date
# 0     3PS - Sent  07/01/2015  06/30/2024
# 1     3PS - Sent  07/01/2019  06/30/2023
# 2     3PS - Sent  08/15/2022  06/30/2023
# 3     3PS - Sent  07/01/2022  06/30/2023
# 4     3PS - Sent  07/07/2022  07/06/2024
# ...          ...         ...         ...
# 1371  3PS - Sent  03/06/2017  07/31/2023
# 1372  3PS - Sent  07/01/2016  06/30/2025
# 1373  3PS - Sent  03/17/2014  03/16/2024
# 1374  3PS - Sent  06/20/2013  06/19/2023
# 1375  3PS - Sent  07/01/2013  06/30/2023
#
# [1376 rows x 10 columns]

# %%
#To get the frequency by levels
contract_data["Organization"].value_counts()
# Out:
# Organization
# CMS - Central Management Services                            809
# DoIT - Department of Innovation and Technology               164
# DHS - Human Services                                          80
# DOT - Transportation                                          56
# ISP - Illinois State Police                                   56
# HDA - Housing Development Authority                           47
# MIL - Military Affairs                                        44
# DOC - Corrections                                             37
# EPA - Environmental Protection Agency                         12
# DPH - Public Health                                           11
# CPOGS - CPO Office for General Services                       10
# DNR - Natural Resources                                        8
# DES - Employment Security                                      8
# FPR - Department of Financial and Professional Regulation      7
# EMA - Emergency Management Agency                              6
# HFS - Healthcare and Family Services                           5
# WCC - Illinois Worker's Compensation Commission                4
# LOT - Lottery                                                  2
# DJJ - Department of Juvenile Justice                           2
# CFS - Children and Family Services                             1
# THA - Toll Highway Authority                                   1
# ICC - Illinois Commerce Commission                             1
# CEI - Commission on Equity and Inclusion                       1
# EEC - Executive Ethics Commission                              1
# REV - Revenue                                                  1
# ALPLM - Abraham Lincoln Presidential Library and Museum        1
# SBE - State Board of Education                                 1
# Name: count, dtype: int64

# %%
#To get the total number of contracts
contract_data["Organization"].value_counts().sum()

# less than 1 percent will be plotted seperatedly and referred to as others
# other categories outside cms will be plotted
# Out:
# 1376

# %%
#Group the organizations by total number of contracts
contract_data_bar = contract_data.groupby('Organization').count()[['Status']].reset_index()
contract_data_bar
# Out:
#                                          Organization  Status
# 0   ALPLM - Abraham Lincoln Presidential Library a...       1
# 1            CEI - Commission on Equity and Inclusion       1
# 2                  CFS - Children and Family Services       1
# 3                   CMS - Central Management Services     809
# 4             CPOGS - CPO Office for General Services      10
# 5                           DES - Employment Security       8
# 6                                DHS - Human Services      80
# 7                DJJ - Department of Juvenile Justice       2
# 8                             DNR - Natural Resources       8
# 9                                   DOC - Corrections      37
# 10                               DOT - Transportation      56
# 11                                DPH - Public Health      11
# 12     DoIT - Department of Innovation and Technology     164
# 13                  EEC - Executive Ethics Commission       1
# 14                  EMA - Emergency Management Agency       6
# 15              EPA - Environmental Protection Agency      12
# 16  FPR - Department of Financial and Professional...       7
# 17                HDA - Housing Development Authority      47
# 18               HFS - Healthcare and Family Services       5
# 19                 ICC - Illinois Commerce Commission       1
# 20                        ISP - Illinois State Police      56
# 21                                      LOT - Lottery       2
# 22                             MIL - Military Affairs      44
# 23                                      REV - Revenue       1
# 24                     SBE - State Board of Education       1
# 25                       THA - Toll Highway Authority       1
# 26    WCC - Illinois Worker's Compensation Commission       4

# %%
#CMS - Central Management Services 809 is 58.6 percent of the contracts
# We are creating a bar graph of the ~ 41 percent left
# The 1 percent of contracts will be represented on a different graph

contract_data_bar2 = contract_data_bar[contract_data_bar['Status'] < 809]
contract_data_bar2 = contract_data_bar2[contract_data_bar2['Status'] > 13]
#contract_data_bar2

# %%
#sort the values of the total 41%
contract_data_bar2.sort_values('Status', inplace= True)
contract_data_bar2
# Out:
#                                       Organization  Status
# 9                                DOC - Corrections      37
# 22                          MIL - Military Affairs      44
# 17             HDA - Housing Development Authority      47
# 10                            DOT - Transportation      56
# 20                     ISP - Illinois State Police      56
# 6                             DHS - Human Services      80
# 12  DoIT - Department of Innovation and Technology     164

# %%
plt.figure(figsize=(7,5)) 
plt.barh(y = contract_data_bar2['Organization'], width= contract_data_bar2['Status'])
plt.xlabel('Total Bids')                      # x-label added
plt.ylabel('State Departments')          # y-label added
plt.title('Awareded Contracts by State Department(Between 2%- 48%)')  # title added
plt.show()

# %%
# create a bar chart for the 1 percent
contract_data_bar3 = contract_data_bar[contract_data_bar['Status'] < 809]
contract_data_bar3 = contract_data_bar3[contract_data_bar3['Status'] < 13]
contract_data_bar3
# Out:
#                                          Organization  Status
# 0   ALPLM - Abraham Lincoln Presidential Library a...       1
# 1            CEI - Commission on Equity and Inclusion       1
# 2                  CFS - Children and Family Services       1
# 4             CPOGS - CPO Office for General Services      10
# 5                           DES - Employment Security       8
# 7                DJJ - Department of Juvenile Justice       2
# 8                             DNR - Natural Resources       8
# 11                                DPH - Public Health      11
# 13                  EEC - Executive Ethics Commission       1
# 14                  EMA - Emergency Management Agency       6
# 15              EPA - Environmental Protection Agency      12
# 16  FPR - Department of Financial and Professional...       7
# 18               HFS - Healthcare and Family Services       5
# 19                 ICC - Illinois Commerce Commission       1
# 21                                      LOT - Lottery       2
# 23                                      REV - Revenue       1
# 24                     SBE - State Board of Education       1
# 25                       THA - Toll Highway Authority       1
# 26    WCC - Illinois Worker's Compensation Commission       4

# %%
contract_data_bar3.sort_values('Status', inplace= True)
contract_data_bar3
# Out:
#                                          Organization  Status
# 0   ALPLM - Abraham Lincoln Presidential Library a...       1
# 1            CEI - Commission on Equity and Inclusion       1
# 2                  CFS - Children and Family Services       1
# 24                     SBE - State Board of Education       1
# 23                                      REV - Revenue       1
# 19                 ICC - Illinois Commerce Commission       1
# 13                  EEC - Executive Ethics Commission       1
# 25                       THA - Toll Highway Authority       1
# 7                DJJ - Department of Juvenile Justice       2
# 21                                      LOT - Lottery       2
# 26    WCC - Illinois Worker's Compensation Commission       4
# 18               HFS - Healthcare and Family Services       5
# 14                  EMA - Emergency Management Agency       6
# 16  FPR - Department of Financial and Professional...       7
# 8                             DNR - Natural Resources       8
# 5                           DES - Employment Security       8
# 4             CPOGS - CPO Office for General Services      10
# 11                                DPH - Public Health      11
# 15              EPA - Environmental Protection Agency      12

# %%
plt.figure(figsize=(7,5)) 
plt.barh(y = contract_data_bar3['Organization'], width= contract_data_bar3['Status'])
plt.xlabel('Total Bids')                      # x-label added
plt.ylabel('State Departments')          # y-label added
plt.title('Bottom 1% of Awareded Contracts by State Department')  # title added
plt.show()
