# %%
#import libraries
import numpy as np
import pandas as pd
import geopandas as gpd
import fiona
import folium
import matplotlib.pyplot as plt

# %%
# Read in shapefile
# Downloaded from https://www2.census.gov/geo/tiger/GENZ2018/shp/cb_2018_us_county_5m.zip

shape_data = gpd.read_file("https://www2.census.gov/geo/tiger/GENZ2018/shp/cb_2018_us_county_5m.zip")

shape_data.head(3)
# Out:
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID      NAME LSAD  \
# 0      39      071  01074048  0500000US39071  39071  Highland   06
# 1      06      003  01675840  0500000US06003  06003    Alpine   06
# 2      12      033  00295737  0500000US12033  12033  Escambia   06
#
#         ALAND     AWATER                                           geometry
# 0  1432479992   12194983  POLYGON ((-83.86976 39.05553, -83.86568 39.247...
# 1  1912292630   12557304  POLYGON ((-120.07248 38.50987, -120.07239 38.7...
# 2  1701544502  563927612  POLYGON ((-87.62999 30.87766, -87.62946 30.880...

# %%
# Filter to only counties in Illinois using StateFP column = 17 
shape_data = shape_data.loc[(shape_data['STATEFP'] == "17")]

shape_data.head(3)
# Out:
#    STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID      NAME LSAD  \
# 3       17      101  00424252  0500000US17101  17101  Lawrence   06
# 22      17      093  00424248  0500000US17093  17093   Kendall   06
# 57      17      139  01784885  0500000US17139  17139  Moultrie   06
#
#         ALAND    AWATER                                           geometry
# 3   963936864   5077783  POLYGON ((-87.91028 38.57493, -87.90811 38.850...
# 22  829468028   5136619  POLYGON ((-88.60349 41.71358, -88.60193 41.719...
# 57  870123798  22102741  POLYGON ((-88.81271 39.74049, -88.75784 39.739...

# %%
# Read in contract  csv file
contract_data = pd.read_csv("../IL_CEI/can-summer-2023/data/raw/contracts/illinois_bidbuy_contracts_as_of_20230614.csv")
# make the company name lower case
contract_data["Vendor"] = contract_data.Vendor.str.lower()
contract_data.head(3)
# Out:
#       Contract / Blanket #  Bid Solicitation #  \
# 0               CIB6354390                 NaN
# 1               CIB5736630                 NaN
# 2  23-563WCC-WCC56-P-39787                 NaN
#
#                               Description                      Vendor  \
# 0                      Prescription Drugs  caremarkpcs health, l.l.c.
# 1     ConnectYourCare - Flexible Spending        connectyourcare, llc
# 2  Sole Source- WCRI CompScope Reports 23                        wcri
#
#   Type Code Dollars Spent to Date  \
# 0         B                 $0.00
# 1         A                 $0.00
# 2         D                 $0.00
#
#                                       Organization      Status  Begin Date  \
# 0                CMS - Central Management Services  3PS - Sent  07/01/2015
# 1                CMS - Central Management Services  3PS - Sent  07/01/2019
# 2  WCC - Illinois Worker's Compensation Commission  3PS - Sent  08/15/2022
#
#      End Date
# 0  06/30/2024
# 1  06/30/2023
# 2  06/30/2023

# %%
# Split County Column for an easy merge with shape_data dataframe by removing the $ sign
contract_data[["Dollars Split", "Dollars Spent to Date"]] = contract_data["Dollars Spent to Date"].str.split('$', expand=True).astype(str)
contract_data
# Out:
#          Contract / Blanket #  Bid Solicitation #  \
# 0                  CIB6354390                 NaN
# 1                  CIB5736630                 NaN
# 2     23-563WCC-WCC56-P-39787                 NaN
# 3     23-563WCC-WCC56-P-38456                 NaN
# 4     23-551HDA-LEGAL-P-39047                 NaN
# ...                       ...                 ...
# 1371     17-416CMS-BOSS4-P-99                 NaN
# 1372     17-416CMS-BOSS4-P-39                 NaN
# 1373               14Z0879001                 NaN
# 1374               13Z1819001                 NaN
# 1375               000MY14222                 NaN
#
#                                    Description  \
# 0                           Prescription Drugs
# 1          ConnectYourCare - Flexible Spending
# 2       Sole Source- WCRI CompScope Reports 23
# 3            EDI Hosting and Maintenance FY 23
# 4        Foley & Lardner Bond Counsel (Exempt)
# ...                                        ...
# 1371       JPMC PAPER AND ENVELOPES SMALL QTYS
# 1372               MC Fleet Fuel Card Services
# 1373      Pharmacy Benefits Management (PBMS)
# 1374  HFS MMIS Upgrade Project Expert Services
# 1375   SBE: Student Information System Support
#
#                                            Vendor Type Code  \
# 0                      caremarkpcs health, l.l.c.         B
# 1                            connectyourcare, llc         A
# 2                                            wcri         D
# 3                                      ebix, inc.         C
# 4                             foley & lardner llp         Z
# ...                                           ...       ...
# 1371                                midland paper         A
# 1372                                     wex bank         B
# 1373   change healthcare pharmacy solutions, inc.         B
# 1374       cognizant technology solutions us corp         B
# 1375  international business machines corporation         B
#
#      Dollars Spent to Date                                     Organization  \
# 0                     0.00                CMS - Central Management Services
# 1                     0.00                CMS - Central Management Services
# 2                     0.00  WCC - Illinois Worker's Compensation Commission
# 3                     0.00  WCC - Illinois Worker's Compensation Commission
# 4                     0.00              HDA - Housing Development Authority
# ...                    ...                                              ...
# 1371          4,502,328.93                CMS - Central Management Services
# 1372            279,800.00                CMS - Central Management Services
# 1373                  0.00             HFS - Healthcare and Family Services
# 1374                  0.00             HFS - Healthcare and Family Services
# 1375                  0.00                   SBE - State Board of Education
#
#           Status  Begin Date    End Date Dollars Split
# 0     3PS - Sent  07/01/2015  06/30/2024
# 1     3PS - Sent  07/01/2019  06/30/2023
# 2     3PS - Sent  08/15/2022  06/30/2023
# 3     3PS - Sent  07/01/2022  06/30/2023
# 4     3PS - Sent  07/07/2022  07/06/2024
# ...          ...         ...         ...           ...
# 1371  3PS - Sent  03/06/2017  07/31/2023
# 1372  3PS - Sent  07/01/2016  06/30/2025
# 1373  3PS - Sent  03/17/2014  03/16/2024
# 1374  3PS - Sent  06/20/2013  06/19/2023
# 1375  3PS - Sent  07/01/2013  06/30/2023
#
# [1376 rows x 11 columns]

# %%
#remove the , in the Dollars Spent to Date
contract_data['Dollars Spent to Date'] = contract_data['Dollars Spent to Date'].str.replace(',', '')

# %%
#convert the Dollars Spent to Date to float
contract_data['Dollars Spent to Date'] = contract_data['Dollars Spent to Date'].astype(float)

# %%
# confirming if things worked
type(contract_data['Dollars Split'][0])

contract_data['Dollars Split'].describe()
# Out:
# count     1376
# unique       1
# top
# freq      1376
# Name: Dollars Split, dtype: object

# %%
# Load vendor data so as to get the zip codes
vendor_data = pd.read_csv("../IL_CEI/can-summer-2023/data/raw/vendors/illinois_state_vendor_registry_as_of_20230614.csv", encoding='cp1252', dtype=str)
vendor_data = vendor_data[['Company Name', 'DBA Name', 'Contact Person', 'Address', 'City',
       'State', 'Zip', 'Phone', 'Fax', 'Email']]  
vendor_data = vendor_data.dropna(subset='Zip')
vendor_data['Zip'] = vendor_data['Zip'].str.replace('\t', '')
vendor_data

# make the company name lower case
vendor_data["Company Name"] = vendor_data["Company Name"].str.lower()
vendor_data
# Out:
#                              Company Name               DBA Name  \
# 0                  'd' construction, inc.                    NaN
# 1       #1 professional cleaning services                    NaN
# 2     *prado & renteria cpas, prof. corp.                  Corp.
# 3      @veterans construction group, llc.                    NaN
# 4                           0x global llc                    NaN
# ...                                   ...                    ...
# 3537                 zirin consulting llc                    NaN
# 3538                     zoi incorporated  ZOI Global Consulting
# 3539             zonatherm products, inc.                    NaN
# 3540                     zuber lawler llp                    NaN
# 3541        zuriel medical staffing, inc.                    NaN
#
#           Contact Person                         Address           City State  \
# 0           Lori Pierard             1488 SOUTH BROADWAY      COAL CITY    IL
# 1         Howard Glasper                    2205 Mayfair    Westchester    IL
# 2         Guadalupe Soto      1837 South Michigan Avenue        Chicago    IL
# 3     Michael Palaguachi                  2608 W 25th St        Chicago    IL
# 4         Adrian Zaharia   6177 N Lincoln Ave, Suite 306        Chicago    IL
# ...                  ...                             ...            ...   ...
# 3537        Joshua Zirin            926 Monticello Drive     Naperville    IL
# 3538    Susanna Alvarado         998 Church St, Unit 405       Glenview    IL
# 3539     Courtney Curtis               875 Busch Parkway  Buffalo Grove    IL
# 3540     Martin P Greene  111 W Jackson Blvd, Suite 1700        Chicago    IL
# 3541        Gifty Appiah   925 N Plum Grove Rd, Suite C.     Schaumburg    IL
#
#         Zip         Phone           Fax                              Email
# 0     60416  815-634-2555           NaN     k.liebermann@dconstruction.com
# 1     60154  708-574-5547  000-000-0000                  1pcs888@gmail.com
# 2     60616  312-788-1450  312-567-1360            rfear@pradorenteria.com
# 3     60608  773-951-5755           NaN  procurement@vets-construction.com
# 4     60659  312-473-7414           NaN             estimating@0xglobal.co
# ...     ...           ...           ...                                ...
# 3537  60563  630-631-9692           NaN           josh@zirinconsulting.com
# 3538  60025  312-340-7060           NaN        susanna.alvarado@zoiinc.com
# 3539  60089  847-541-1129  847-541-1750              ccurtis@zonatherm.com
# 3540  60604  312-346-1100  213-596-5621                eletts@zuberlaw.com
# 3541  60173  224-200-9036  847-744-5134              info@zurielagency.com
#
# [3542 rows x 10 columns]

# %%
# merge contract and vendor data

contract_data_pro = pd.merge(contract_data, vendor_data, left_on = 'Vendor', right_on = "Company Name", how = "inner")

contract_data_pro
# Out:
#         Contract / Blanket #  Bid Solicitation #  \
# 0    23-494DOT-DISTR-P-51168                 NaN
# 1    23-493ISP-OPERA-P-44593                 NaN
# 2    23-466MIL-LNCCH-P-43107                 NaN
# 3    23-444DHS-MIS44-P-42160                 NaN
# 4    23-444DHS-MIS44-P-42158                 NaN
# ..                       ...                 ...
# 401   17-448DOIT-APP44-P-168                 NaN
# 402   17-448DOIT-APP44-P-164                 NaN
# 403   17-448DOIT-APP44-P-158                 NaN
# 404   17-448DOIT-APP44-P-154                 NaN
# 405   17-448DOIT-APP44-P-148                 NaN
#
#                                            Description  \
# 0                                    Poly Liner - 931A
# 1          DCI-Analytic software and equipment -IFB-ah
# 2                             LCA-Desktop Computers-SE
# 3                      23-OCAPS Project Mgmnt Software
# 4                            23-IES ScanOptics Maint.
# ..                                                 ...
# 401  JPMC DOIT - ITRP Terms and Conditions Only - I...
# 402  JPMX DOIT - ITRP Terms and Conditions Only - G...
# 403                   ITRP - terms and conditions only
# 404                   ITRP - terms and conditions only
# 405                   ITRP - Terms and Conditions only
#
#                                        Vendor Type Code  \
# 0                 energy culvert company, llc         C
# 1                 national tek services, inc.         A
# 2                 national tek services, inc.         C
# 3                 national tek services, inc.         C
# 4                 national tek services, inc.         C
# ..                                        ...       ...
# 401                       io datasphere, inc.         A
# 402                       gnc consulting, inc         A
# 403  electronic knowledge interchange company         A
# 404            csg government solutions, inc.         A
# 405           catalyst consulting group, inc.         A
#
#      Dollars Spent to Date                                    Organization  \
# 0                      0.0                            DOT - Transportation
# 1                 417038.0                     ISP - Illinois State Police
# 2                      0.0                          MIL - Military Affairs
# 3                      0.0                            DHS - Human Services
# 4                      0.0                            DHS - Human Services
# ..                     ...                                             ...
# 401                    0.0  DoIT - Department of Innovation and Technology
# 402                    0.0  DoIT - Department of Innovation and Technology
# 403                    0.0  DoIT - Department of Innovation and Technology
# 404                    0.0  DoIT - Department of Innovation and Technology
# 405                    0.0  DoIT - Department of Innovation and Technology
#
#          Status  Begin Date    End Date  ...  \
# 0    3PS - Sent  05/17/2023  08/31/2023  ...
# 1    3PS - Sent  12/20/2022  12/19/2027  ...
# 2    3PS - Sent  10/25/2022  06/30/2023  ...
# 3    3PS - Sent  11/01/2022  10/31/2025  ...
# 4    3PS - Sent  11/01/2022  10/31/2023  ...
# ..          ...         ...         ...  ...
# 401  3PS - Sent  11/14/2016  06/30/2026  ...
# 402  3PS - Sent  11/14/2016  06/30/2026  ...
# 403  3PS - Sent  11/11/2016  06/30/2026  ...
# 404  3PS - Sent  11/30/2016  06/30/2026  ...
# 405  3PS - Sent  11/14/2016  06/30/2026  ...
#
#                                  Company Name DBA Name  Contact Person  \
# 0                 energy culvert company, llc      NaN    Charlie Kemp
# 1                 national tek services, inc.      NaN    Terry Benzel
# 2                 national tek services, inc.      NaN    Terry Benzel
# 3                 national tek services, inc.      NaN    Terry Benzel
# 4                 national tek services, inc.      NaN    Terry Benzel
# ..                                        ...      ...             ...
# 401                       io datasphere, inc.      NaN    Susan Farmer
# 402                       gnc consulting, inc      NaN      Janet Webb
# 403  electronic knowledge interchange company      NaN       JOSE CRUZ
# 404            csg government solutions, inc.      NaN  John Walsworth
# 405           catalyst consulting group, inc.      NaN     Eric Talwar
#
#                               Address          City State    Zip  \
# 0                  PO Box 640, Energy        Energy    IL  62933
# 1                             POBox 6  Libertyville    IL  60048
# 2                             POBox 6  Libertyville    IL  60048
# 3                             POBox 6  Libertyville    IL  60048
# 4                             POBox 6  Libertyville    IL  60048
# ..                                ...           ...   ...    ...
# 401                       PO Box 1444   Warrenville    IL  60555
# 402               21195 S Lagrange Rd     Frankfort    IL  60423
# 403     33 W. MONROE STREET, STE 1050       CHICAGO    IL  60603
# 404         180 N. STETSON SUITE 3200       CHICAGO    IL  60601
# 405  211 West Wacker Drive, Suite 450       Chicago    IL  60606
#
#             Phone           Fax                            Email
# 0    618-942-7381  618-942-7834                 nrgcmp@yahoo.com
# 1    847-850-1201  847-850-1204             sales@tekservinc.com
# 2    847-850-1201  847-850-1204             sales@tekservinc.com
# 3    847-850-1201  847-850-1204             sales@tekservinc.com
# 4    847-850-1201  847-850-1204             sales@tekservinc.com
# ..            ...           ...                              ...
# 401  630-520-0260  630-381-1336         sfarmer@iodatasphere.com
# 402  815-469-7255  779-203-9281  garry.cooper@gnc-consulting.com
# 403  312-236-0903  312-236-2022       finance@eki-consulting.com
# 404  312-444-2760  312-444-2760          finance@csgdelivers.com
# 405  312-499-2000  312-629-0751      cindy.talwar@catconsult.com
#
# [406 rows x 21 columns]

# %%
#merge contract_data_pro with illinois_zip_county 
illinois_zip_count_data = pd.read_csv("../IL_CEI/can-summer-2023/data/self_add/Illinois_zip_county.csv")
illinois_zip_count_data
# Out:
#         Zip    County
# 0     60002      Lake
# 1     60004      Cook
# 2     60005      Cook
# 3     60010      Lake
# 4     60012   Mchenry
# ...     ...       ...
# 1292  62994   Jackson
# 1293  62995   Johnson
# 1294  62996   Pulaski
# 1295  62998     Union
# 1296  62999  Franklin
#
# [1297 rows x 2 columns]

# %%
#convert zip to int for easy merge
contract_data_pro.Zip = contract_data_pro.Zip.astype('int')
contract_data_pro.Zip.dtypes
# Out:
# dtype('int64')

# %%
# merge contract_data_pro and illinois_zip_count_data

contract_data_pro2= contract_data_pro.merge(illinois_zip_count_data, on='Zip', how = "inner")

#contract_data_pro2 = pd.merge(contract_data_pro, illinois_zip_count_data, left_on = 'Zip', right_on = "Zip", how = "inner")

contract_data_pro2
# Out:
#         Contract / Blanket #  Bid Solicitation #  \
# 0    23-494DOT-DISTR-P-51168                 NaN
# 1    23-493ISP-OPERA-P-44593                 NaN
# 2    23-466MIL-LNCCH-P-43107                 NaN
# 3    23-444DHS-MIS44-P-42160                 NaN
# 4    23-444DHS-MIS44-P-42158                 NaN
# ..                       ...                 ...
# 380   17-448DOIT-APP44-P-170                 NaN
# 381   17-448DOIT-APP44-P-169                 NaN
# 382   17-448DOIT-APP44-P-168                 NaN
# 383   17-448DOIT-APP44-P-164                 NaN
# 384   17-448DOIT-APP44-P-158                 NaN
#
#                                            Description  \
# 0                                    Poly Liner - 931A
# 1          DCI-Analytic software and equipment -IFB-ah
# 2                             LCA-Desktop Computers-SE
# 3                      23-OCAPS Project Mgmnt Software
# 4                            23-IES ScanOptics Maint.
# ..                                                 ...
# 380                   ITRP - terms and conditions only
# 381  JPMC DOIT - ITRP Terms and Conditions Only - I...
# 382  JPMC DOIT - ITRP Terms and Conditions Only - I...
# 383  JPMX DOIT - ITRP Terms and Conditions Only - G...
# 384                   ITRP - terms and conditions only
#
#                                        Vendor Type Code  \
# 0                 energy culvert company, llc         C
# 1                 national tek services, inc.         A
# 2                 national tek services, inc.         C
# 3                 national tek services, inc.         C
# 4                 national tek services, inc.         C
# ..                                        ...       ...
# 380                  kestner consulting, inc.         A
# 381                    iyka enterprises, inc.         A
# 382                       io datasphere, inc.         A
# 383                       gnc consulting, inc         A
# 384  electronic knowledge interchange company         A
#
#      Dollars Spent to Date                                    Organization  \
# 0                      0.0                            DOT - Transportation
# 1                 417038.0                     ISP - Illinois State Police
# 2                      0.0                          MIL - Military Affairs
# 3                      0.0                            DHS - Human Services
# 4                      0.0                            DHS - Human Services
# ..                     ...                                             ...
# 380                    0.0  DoIT - Department of Innovation and Technology
# 381                    0.0  DoIT - Department of Innovation and Technology
# 382                    0.0  DoIT - Department of Innovation and Technology
# 383                    0.0  DoIT - Department of Innovation and Technology
# 384                    0.0  DoIT - Department of Innovation and Technology
#
#          Status  Begin Date    End Date  ...          DBA Name  \
# 0    3PS - Sent  05/17/2023  08/31/2023  ...               NaN
# 1    3PS - Sent  12/20/2022  12/19/2027  ...               NaN
# 2    3PS - Sent  10/25/2022  06/30/2023  ...               NaN
# 3    3PS - Sent  11/01/2022  10/31/2025  ...               NaN
# 4    3PS - Sent  11/01/2022  10/31/2023  ...               NaN
# ..          ...         ...         ...  ...               ...
# 380  3PS - Sent  11/30/2016  06/30/2026  ...               KCI
# 381  3PS - Sent  02/03/2017  06/30/2026  ...  Sriranga Digital
# 382  3PS - Sent  11/14/2016  06/30/2026  ...               NaN
# 383  3PS - Sent  11/14/2016  06/30/2026  ...               NaN
# 384  3PS - Sent  11/11/2016  06/30/2026  ...               NaN
#
#             Contact Person                        Address          City State  \
# 0             Charlie Kemp             PO Box 640, Energy        Energy    IL
# 1             Terry Benzel                        POBox 6  Libertyville    IL
# 2             Terry Benzel                        POBox 6  Libertyville    IL
# 3             Terry Benzel                        POBox 6  Libertyville    IL
# 4             Terry Benzel                        POBox 6  Libertyville    IL
# ..                     ...                            ...           ...   ...
# 380           Doug Kestner          5120 Mechanicsburg Rd   Springfield    IL
# 381  Poonam Gupta-Krishnan            2707 Turnberry Road   St. Charles    IL
# 382           Susan Farmer                    PO Box 1444   Warrenville    IL
# 383             Janet Webb            21195 S Lagrange Rd     Frankfort    IL
# 384              JOSE CRUZ  33 W. MONROE STREET, STE 1050       CHICAGO    IL
#
#        Zip         Phone           Fax                            Email  \
# 0    62933  618-942-7381  618-942-7834                 nrgcmp@yahoo.com
# 1    60048  847-850-1201  847-850-1204             sales@tekservinc.com
# 2    60048  847-850-1201  847-850-1204             sales@tekservinc.com
# 3    60048  847-850-1201  847-850-1204             sales@tekservinc.com
# 4    60048  847-850-1201  847-850-1204             sales@tekservinc.com
# ..     ...           ...           ...                              ...
# 380  62712  217-836-8165           NaN           doug.kestner@gmail.com
# 381  60174  630-372-3900  630-561-3852                  poonam@iyka.com
# 382  60555  630-520-0260  630-381-1336         sfarmer@iodatasphere.com
# 383  60423  815-469-7255  779-203-9281  garry.cooper@gnc-consulting.com
# 384  60603  312-236-0903  312-236-2022       finance@eki-consulting.com
#
#          County
# 0    Williamson
# 1          Lake
# 2          Lake
# 3          Lake
# 4          Lake
# ..          ...
# 380    Sangamon
# 381        Kane
# 382      Dupage
# 383        Will
# 384        Cook
#
# [385 rows x 22 columns]

# %%
#group the total contract by county
contract_data_pro2_group = contract_data_pro2.groupby('County').mean(numeric_only = True)[['Dollars Spent to Date']].reset_index()
contract_data_pro2_group
contract_data_pro2_group["Dollars Spent to Date"].describe()
# Out:
# count    4.700000e+01
# mean     8.679004e+05
# std      3.030727e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      4.479440e+04
# 75%      4.898503e+05
# max      2.007652e+07
# Name: Dollars Spent to Date, dtype: float64

# %%
# Rename the Column "NAME" to "County"

shape_data = shape_data.rename(columns = {'NAME': 'County'})

# %%
# contract_data_pro2_groupdataframe with shape_data dataframe
shape_data_full = shape_data.merge(contract_data_pro2_group, on="County", how = "outer")
shape_data_full
# Out:
#     STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID       County LSAD  \
# 0        17      101  00424252  0500000US17101  17101     Lawrence   06
# 1        17      093  00424248  0500000US17093  17093      Kendall   06
# 2        17      139  01784885  0500000US17139  17139     Moultrie   06
# 3        17      049  00424226  0500000US17049  17049    Effingham   06
# 4        17      103  00424253  0500000US17103  17103          Lee   06
# ..      ...      ...       ...             ...    ...          ...  ...
# 104     NaN      NaN       NaN             NaN    NaN     La Salle  NaN
# 105     NaN      NaN       NaN             NaN    NaN    Mcdonough  NaN
# 106     NaN      NaN       NaN             NaN    NaN      Mchenry  NaN
# 107     NaN      NaN       NaN             NaN    NaN       Mclean  NaN
# 108     NaN      NaN       NaN             NaN    NaN  Saint Clair  NaN
#
#             ALAND      AWATER  \
# 0    9.639369e+08   5077783.0
# 1    8.294680e+08   5136619.0
# 2    8.701238e+08  22102741.0
# 3    1.239970e+09   3183217.0
# 4    1.877336e+09  10634483.0
# ..            ...         ...
# 104           NaN         NaN
# 105           NaN         NaN
# 106           NaN         NaN
# 107           NaN         NaN
# 108           NaN         NaN
#
#                                               geometry  Dollars Spent to Date
# 0    POLYGON ((-87.91028 38.57493, -87.90811 38.850...                    NaN
# 1    POLYGON ((-88.60349 41.71358, -88.60193 41.719...                    NaN
# 2    POLYGON ((-88.81271 39.74049, -88.75784 39.739...                    NaN
# 3    POLYGON ((-88.80532 39.21626, -88.47091 39.215...           0.000000e+00
# 4    POLYGON ((-89.63147 41.75813, -89.63026 41.843...                    NaN
# ..                                                 ...                    ...
# 104                                               None           2.007652e+07
# 105                                               None           2.209797e+04
# 106                                               None           2.179533e+04
# 107                                               None           4.051695e+06
# 108                                               None           2.471031e+05
#
# [109 rows x 11 columns]

# %%
shape_data_full['Dollars Spent to Date'] = shape_data_full['Dollars Spent to Date'].fillna(0)

# %%
#then plot

fig, ax = plt.subplots(figsize=(10, 10))

shape_data_full.plot(ax = ax, column='Dollars Spent to Date',legend=True,figsize=(10,10), vmin = 0, vmax = 2.007652e+07, legend_kwds={'label': 'BEP'})
ax.set_axis_off()

# %%
fig, ax = plt.subplots(figsize=(10, 10))

shape_data_full.plot(ax = ax, column='Dollars Spent to Date',legend=True,figsize=(10,10), vmin = 0, vmax = 4.903955e+06, legend_kwds={'label': 'BEP'})
ax.set_axis_off()

# %%
shape_data_full["Dollars Spent to Date"].max()
# Out:
# 20076515.735

# %%
shape_data_full["Dollars Spent to Date"].min()
# Out:
# 0.0

# %%
shape_data_full["Dollars Spent to Date"].describe()
# Out:
# count    1.090000e+02
# mean     3.742323e+05
# std      2.024529e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.057500e+04
# max      2.007652e+07
# Name: Dollars Spent to Date, dtype: float64

# %%
shape_data_full["Dollars Spent to Date"].nlargest()
# Out:
# 104    2.007652e+07
# 75     4.903955e+06
# 107    4.051695e+06
# 58     2.300736e+06
# 101    1.787956e+06
# Name: Dollars Spent to Date, dtype: float64
