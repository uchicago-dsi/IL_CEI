# %% [markdown]
# ### Clean BEP Companies

# %% [markdown]
# _Cleans BEP companies' certifications and cleans and geocodes their physical addresses. Outputs three CSV files: `bep_company_addresses_all.csv`, `bep_company_addresses_physical_geocoded.csv`, and `bep_company_certifications`. NOTE: As a next step, more extensive record linkage should be performed (i.e., consolidating entries that have the same street address and similar names or owners.) We could also get better reseults by normalizing/standardizing the addresses before the forward geocoding step._

# %% [markdown]
# #### Setup

# %%
# Python standard library
import json
import os
import pandas as pd
import time

# HTTP requests
import requests

# Environment variable management
import dotenv

# %%
# Load environment variables into current environment
dotenv.load_dotenv()
# Out:
# True

# %% [markdown]
# #### Load BEP-Certified Vendors

# %%
# Read in BEP certifications dataset into DataFrame
vendor_dir = "../data/raw/vendors"
bep_fname = "illinois_bep_vendor_certifications_as_of_20230614.csv"
bep_df = pd.read_csv(f"{vendor_dir}/{bep_fname}", encoding='cp1252')
bep_df.head(2)
# Out:
#                         Company Name                  DBA Name Owner First  \
# 0  #1 Professional Cleaning Services                       NaN      Howard
# 1                     #9 Design, LLC  North Arrow Architecture    Dulcinea
#
#   Owner Last             Physical Address         City State      Zip  \
# 0    Glasper                 2205 Mayfair  Westchester    IL  60154.0
# 1    Gillman  524 West Saint Charles Road   Villa Park    IL  60181.0
#
#               Mailing Address       City.1  ... Certification Type  \
# 0               P.O. Box 7555  Westchester  ...                MBE
# 1  28 East Saint Charles Road   Villa Park  ...                WBE
#
#           Ethnicity  Gender     Renewal  Expiration  \
# 0  African American    Male   8/17/2023   8/17/2029
# 1         Caucasian  Female  12/15/2023  12/15/2023
#
#                                           Capability  County  \
# 0           91039\tJanitorial and Custodial Services    Cook
# 1  NIGP\t90714\tArchitectural Services, Non-Licen...  DuPage
#
#               Region Reciprocal Certification Agency  \
# 0      Metro Chicago                             NaN
# 1  Northern Illinois                            WBDC
#
#                                      Commodity Codes
# 0          91039 - Janitorial and Custodial Services
# 1  90714 - Architectural Services, Non-Licensed (...
#
# [2 rows x 27 columns]

# %% [markdown]
# #### Clean BEP Certifications

# %%
# Drop records missing a certification type
# NOTE: The system generating the data, "B2GNow", leaves the last
# few rows in the CSV file empty before including a line of metadata:
# "Generated from the B2Gnow System".
print("There are", len(bep_df), "vendor certification rows in the DataFrame.")
idx_to_drop = bep_df.query("`Certification Type` != `Certification Type`").index
bep_df = bep_df.drop(index=idx_to_drop)
print("After dropping blank records,", len(bep_df), "rows remain.")
# Out:
# There are 7328 vendor certification rows in the DataFrame.
# After dropping blank records, 7325 rows remain.

# %%
# Create new column for agency certification
bep_df['Certification'] = bep_df['Agency'] + ' ' + bep_df['Certification Type']

# %%
# Merge on company name and create new certification columns
bep_certs_df = bep_df.loc[:, ['Company Name', 'Certification', 'Renewal', 'Expiration']]
bep_certs_df.head(10)
# Out:
#                                Company Name Certification     Renewal  \
# 0         #1 Professional Cleaning Services   CEI BEP MBE   8/17/2023
# 1                            #9 Design, LLC   CEI BEP WBE  12/15/2023
# 2                  'Bouche' Enterprises LLC   Chicago MBE    4/1/2024
# 3                  'Bouche' Enterprises LLC   Chicago WBE    4/1/2024
# 4                  'Bouche' Enterprises LLC  CEI BEP WMBE    4/1/2024
# 5  'Merica Made Painting & Decorating Corp.   Chicago MBE    9/1/2023
# 6                    *VDR Development Group   CEI BEP MBE   1/18/2024
# 7                    @Contract Partners LLC   Chicago WBE   6/15/2023
# 8                    @Contract Partners LLC   CEI BEP WBE   7/15/2023
# 9        @Veterans Construction Group, LLC.   CEI BEP MBE   9/14/2023
#
#    Expiration
# 0   8/17/2029
# 1  12/15/2023
# 2    4/1/2024
# 3    4/1/2024
# 4    4/1/2024
# 5    9/1/2023
# 6   1/18/2024
# 7   5/15/2026
# 8   7/15/2023
# 9   9/14/2028

# %%
# Write certifications to file
fpath = "../data/clean/bep_company_certifications.csv"
bep_certs_df.to_csv(fpath, index=False)

# %% [markdown]
# #### Clean BEP Company Addresses

# %%
def build_address_dataset(
    bep_df: pd.DataFrame,
    company_name_col: str,
    street_addr_col: str,
    city_col: str,
    state_col: str,
    zip_col: str,
    address_type: str) -> pd.DataFrame:
    """
    Builds an address dataset.
    """
    # Take subset of BEP DataFrame
    str_addr_cols = [street_addr_col, city_col]
    addr_cols = str_addr_cols + [state_col, zip_col]
    subset_cols = [company_name_col] + addr_cols
    subset = bep_df.copy()[subset_cols]

    # Standardize capitalization
    def correct_case(address: str):
        corrected = []
        for word in address.split():
            if word[0].isdigit():
                corrected.append(word)
            else:
                corrected.append(word.title())
        return ' '.join(corrected)
    subset[str_addr_cols] = subset[str_addr_cols].apply(lambda s: s.apply(correct_case))

    # Standardize data type of zip code columns
    subset[zip_col] = subset[zip_col].astype(int)

    # Add new column for address type
    subset["Address Type"] = address_type

    # Define local function to dedupe addresses
    def dedupe(df):
        if len(df) == 1:
            return df
        is_po = lambda s: s.lower().strip().startswith("po")
        df = df[~df[street_addr_col].apply(is_po)]
        return df.head(1)
    
    # Define final column mapping
    col_map = {
        company_name_col: "Company Name",
        "Address Type": "Address Type",
        street_addr_col: "Street",
        city_col: "City",
        state_col: "State",
        zip_col: "ZIP Code"
    }
    
    # Reshape DataFrame
    addresses_df = (subset
        .groupby(company_name_col)
        .apply(dedupe)
        .drop(columns=company_name_col)
        .reset_index()
        .drop(columns="level_1")
        .rename(columns=col_map)
        .loc[:, list(col_map.values())])
    
    return addresses_df

# %%
# Correct physical addresses
physical_address_df = build_address_dataset(
    bep_df,
    company_name_col="Company Name",
    street_addr_col="Physical Address",
    city_col="City",
    state_col="State",
    zip_col="Zip",
    address_type="Physical"
)

# Preview DataFrame
physical_address_df.head(10)
# Out:
#                                Company Name Address Type  \
# 0         #1 Professional Cleaning Services     Physical
# 1                            #9 Design, LLC     Physical
# 2                  'Bouche' Enterprises LLC     Physical
# 3  'Merica Made Painting & Decorating Corp.     Physical
# 4                    *VDR Development Group     Physical
# 5      1052 Partners, Inc. dba PeopleCaddie     Physical
# 6                            123 Labor Inc.     Physical
# 7                      1822 Enterprises LLC     Physical
# 8            1st Aerow Valuation Group, LLC     Physical
# 9          1st Call Technical Services, Inc     Physical
#
#                            Street              City State  ZIP Code
# 0                    2205 Mayfair       Westchester    IL     60154
# 1     524 West Saint Charles Road        Villa Park    IL     60181
# 2       3511 North Osceola Avenue           Chicago    IL     60634
# 3               6221 S Austin Ave           Chicago    IL     60638
# 4             168 N Brandon Drive  Glendale Heights    IL     60190
# 5      5600 N River Rd, Suite 800          Rosemont    IL     60018
# 6             8318 Rutherford Ave           Burbank    IL     60459
# 7  4524 S King Dr, Unit 3, Unit 3           Chicago    IL     60653
# 8                2706 E. 76th Pl.           Chicago    IL     60649
# 9             214 Butternut Drive       Bolingbrook    IL     60440

# %%
# Correct mailing addresses
mailing_address_df = build_address_dataset(
    bep_df,
    company_name_col="Company Name",
    street_addr_col="Mailing Address",
    city_col="City.1",
    state_col="State.1",
    zip_col="Zip.1",
    address_type="Mailing"
)

# Preview DataFrame
mailing_address_df.head(10)
# Out:
#                                Company Name Address Type  \
# 0         #1 Professional Cleaning Services      Mailing
# 1                            #9 Design, LLC      Mailing
# 2                  'Bouche' Enterprises LLC      Mailing
# 3  'Merica Made Painting & Decorating Corp.      Mailing
# 4                    *VDR Development Group      Mailing
# 5      1052 Partners, Inc. dba PeopleCaddie      Mailing
# 6                            123 Labor Inc.      Mailing
# 7                      1822 Enterprises LLC      Mailing
# 8            1st Aerow Valuation Group, LLC      Mailing
# 9          1st Call Technical Services, Inc      Mailing
#
#                            Street              City State  ZIP Code
# 0                   P.O. Box 7555       Westchester    IL     60154
# 1      28 East Saint Charles Road        Villa Park    IL     60181
# 2       3511 North Osceola Avenue           Chicago    IL     60634
# 3               6221 S Austin Ave           Chicago    IL     60638
# 4             168 N Brandon Drive  Glendale Heights    IL     60190
# 5      5600 N River Rd, Suite 800          Rosemont    IL     60018
# 6             8318 Rutherford Ave           Burbank    IL     60459
# 7  4524 S King Dr, Unit 3, Unit 3           Chicago    IL     60653
# 8                2706 E. 76th Pl.           Chicago    IL     60649
# 9                    P.O. Box 258       Bolingbrook    IL     60440

# %%
# Combine address datasets
address_df = (pd
    .concat([physical_address_df, mailing_address_df])
    .sort_values(by=['Company Name', 'Address Type']))

# Preview DataFrame
address_df.head(10)
# Out:
#                                Company Name Address Type  \
# 0         #1 Professional Cleaning Services      Mailing
# 0         #1 Professional Cleaning Services     Physical
# 1                            #9 Design, LLC      Mailing
# 1                            #9 Design, LLC     Physical
# 2                  'Bouche' Enterprises LLC      Mailing
# 2                  'Bouche' Enterprises LLC     Physical
# 3  'Merica Made Painting & Decorating Corp.      Mailing
# 3  'Merica Made Painting & Decorating Corp.     Physical
# 4                    *VDR Development Group      Mailing
# 4                    *VDR Development Group     Physical
#
#                         Street              City State  ZIP Code
# 0                P.O. Box 7555       Westchester    IL     60154
# 0                 2205 Mayfair       Westchester    IL     60154
# 1   28 East Saint Charles Road        Villa Park    IL     60181
# 1  524 West Saint Charles Road        Villa Park    IL     60181
# 2    3511 North Osceola Avenue           Chicago    IL     60634
# 2    3511 North Osceola Avenue           Chicago    IL     60634
# 3            6221 S Austin Ave           Chicago    IL     60638
# 3            6221 S Austin Ave           Chicago    IL     60638
# 4          168 N Brandon Drive  Glendale Heights    IL     60190
# 4          168 N Brandon Drive  Glendale Heights    IL     60190

# %%
# Write datasets to file
address_df.to_csv("../data/clean/bep_company_addresses_all.csv", index=False)

# %% [markdown]
# #### Geocode Physical Company Addresses

# %%
# Create DataFrame of unique addresses
physical_df = address_df.copy().query("`Address Type` == 'Physical'")
physical_df.set_index("Company Name", inplace=True)
physical_df['Street'] = physical_df['Street'].str.strip(".")
address_cols = ['Street', 'City', 'State', 'ZIP Code']
unique_address_df = physical_df[address_cols].drop_duplicates()

# Preview DataFrame
unique_address_df.head()
# Out:
#                                                                Street  \
# Company Name
# #1 Professional Cleaning Services                        2205 Mayfair
# #9 Design, LLC                            524 West Saint Charles Road
# 'Bouche' Enterprises LLC                    3511 North Osceola Avenue
# 'Merica Made Painting & Decorating Corp.            6221 S Austin Ave
# *VDR Development Group                            168 N Brandon Drive
#
#                                                       City State  ZIP Code
# Company Name
# #1 Professional Cleaning Services              Westchester    IL     60154
# #9 Design, LLC                                  Villa Park    IL     60181
# 'Bouche' Enterprises LLC                           Chicago    IL     60634
# 'Merica Made Painting & Decorating Corp.           Chicago    IL     60638
# *VDR Development Group                    Glendale Heights    IL     60190

# %%
# Initialize variables
base_url = "http://dev.virtualearth.net/REST/v1/Locations/US/{state}/{zip_code}/{city}/{street_address}"
api_key = os.environ['BING_API_KEY']

# Load cache from disk or create if it doesn't exist
os.makedirs("../data/cache", exist_ok=True)
cache_fpath = "../data/cache/geocoded_addresses.json"
if os.path.exists(cache_fpath):
    with open(cache_fpath) as f:
        cache = json.load(f)
else:
    cache = {}

# Geocode each address
try:
    for idx, row in unique_address_df.iterrows():

        # Log company to be geocoded
        print(f"Geocoding company \"{idx}\".")

        # Skip API call if address has already been geocoded
        if idx in cache:
            print("Company already in cache. Skipping.")
            continue
        
        # Build request URL
        # NOTE: Encoding only used to escape hash symbol
        url = base_url.format(
            state=row['State'],
            zip_code=row['ZIP Code'],
            city=row['City'],
            street_address=row['Street'].strip(',').replace("#", "%23"))
        params = ["verboseplacenames=true", f"key={api_key}"]
        url = f"{url}?{'&'.join(params)}"

        # Attempt to forward geocode address
        r = requests.get(url, timeout=30)

        # Raise exception if geocoding failed
        if not r.ok:
            print(f"The Bing Maps API response returned "
                f"a status code of \"{r.reason} - {r.status_code}\" "
                f"and the text '{r.text}'.")
            continue
            
        # Raise exception if no results returned
        try:
            resource_set = r.json()["resourceSets"][0]
            top_resource = resource_set["resources"][0]
            address = top_resource["address"]
        except (KeyError, IndexError) as e:
            raise Exception("No address results contained in "
                f"Bing Maps API response. {e}")
        
        # Otherwise, parse response for expected properties
        try:
            lat, lon = top_resource['point']['coordinates']
            state = address["adminDistrict"]
            county = address.get("adminDistrict2", "")
            city = address['locality']
            street_address = address.get('addressLine', '')
            confidence = top_resource['confidence']
        except KeyError as e:
            raise Exception("Geocoded response missing "
                f"expected property '{e}'.")

        # Add geocoded address to cache
        cache[idx] = {
            "Latitude": lat,
            "Longitude": lon,
            "Street": street_address,
            "City": city,
            "County": county,
            "State": state,
            "Confidence": confidence
        }

        # Pause before making next request
        time.sleep(1)

except Exception as e:
    # Log error
    print(f"Failed to geocode company addresses. {e}")
    print("Persisting any entries to cache.")
finally:
    with open(cache_fpath, "w") as f:
        json.dump(cache, f, indent=2)

print("Geocoding complete.")
# Out:
# Geocoding company "#1 Professional Cleaning Services".
# Company already in cache. Skipping.
# Geocoding company "#9 Design, LLC".
# Company already in cache. Skipping.
# Geocoding company "'Bouche' Enterprises LLC".
# Company already in cache. Skipping.
# Geocoding company "'Merica Made Painting & Decorating Corp.".
# Company already in cache. Skipping.
# Geocoding company "*VDR Development Group".
# Company already in cache. Skipping.
# Geocoding company "1052 Partners, Inc. dba PeopleCaddie".
# Company already in cache. Skipping.
# Geocoding company "123 Labor Inc.".
# Company already in cache. Skipping.
# Geocoding company "1822 Enterprises LLC".
# Company already in cache. Skipping.
# Geocoding company "1st Aerow Valuation Group, LLC".
# Company already in cache. Skipping.
# Geocoding company "1st Call Technical Services, Inc".
# Company already in cache. Skipping.
# Geocoding company "1st Choice Specialty Services Inc.".
# Company already in cache. Skipping.
# Geocoding company "1st Metropolitan Translation Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "1st Priority Elevator, Co.".
# Company already in cache. Skipping.
# Geocoding company "1st Resource Solutions, LLC".
# Company already in cache. Skipping.
# Geocoding company "2 Code Plumbing, LLC".
# Company already in cache. Skipping.
# Geocoding company "2 Point Perspective, Inc.".
# Company already in cache. Skipping.
# Geocoding company "2 Sons LLC".
# Company already in cache. Skipping.
# Geocoding company "2.718 Marketing, Inc.".
# Company already in cache. Skipping.
# Geocoding company "21 and Trucking, Inc.".
# Company already in cache. Skipping.
# Geocoding company "22Vets LLC".
# Company already in cache. Skipping.
# Geocoding company "2IM Group, LLC".
# Company already in cache. Skipping.
# Geocoding company "2K Consulting, LLC".
# Company already in cache. Skipping.
# Geocoding company "3 Fuerzas Technology Solutions LLC".
# Company already in cache. Skipping.
# Geocoding company "3 Net Wise, Inc.".
# Company already in cache. Skipping.
# Geocoding company "3 R Health Care Products, Inc.".
# Company already in cache. Skipping.
# Geocoding company "3 Sisters Logistics, LLC".
# Company already in cache. Skipping.
# Geocoding company "3 Stop Shop - P.C.".
# Company already in cache. Skipping.
# Geocoding company "314e Corporation".
# Company already in cache. Skipping.
# Geocoding company "321 Co.".
# Company already in cache. Skipping.
# Geocoding company "357 Designs Inc.".
# Company already in cache. Skipping.
# Geocoding company "360 Dump-N-Run, Inc.".
# Company already in cache. Skipping.
# Geocoding company "3As Sign Language Interpreting Services".
# Company already in cache. Skipping.
# Geocoding company "3CD Corporation".
# Company already in cache. Skipping.
# Geocoding company "3Core Systems, Inc.".
# Company already in cache. Skipping.
# Geocoding company "3DS Teams".
# Company already in cache. Skipping.
# Geocoding company "3M Landscaping Corporation".
# Company already in cache. Skipping.
# Geocoding company "4 Consulting, Inc.".
# Company already in cache. Skipping.
# Geocoding company "40 Cal Trucking, Inc.".
# Company already in cache. Skipping.
# Geocoding company "4D Acres Real Estate Group LLC".
# Company already in cache. Skipping.
# Geocoding company "4G Transport Inc".
# Company already in cache. Skipping.
# Geocoding company "4HD Incorporated".
# Company already in cache. Skipping.
# Geocoding company "4LM Services, LLC".
# Company already in cache. Skipping.
# Geocoding company "4N CONSULTANTS, INC.".
# Company already in cache. Skipping.
# Geocoding company "4PL Global Logistics, LLC".
# Company already in cache. Skipping.
# Geocoding company "4S Construction Inc.".
# Company already in cache. Skipping.
# Geocoding company "500 Trucking, Inc.".
# Company already in cache. Skipping.
# Geocoding company "510 Transportation LLC".
# Company already in cache. Skipping.
# Geocoding company "5366 Logistics Corp".
# Company already in cache. Skipping.
# Geocoding company "548 Capital LLC".
# Company already in cache. Skipping.
# Geocoding company "59 Films LLC".
# Company already in cache. Skipping.
# Geocoding company "5T Development Partners LLC".
# Company already in cache. Skipping.
# Geocoding company "606 Digital Inc.".
# Company already in cache. Skipping.
# Geocoding company "606 Specialties and Contracting, LLC".
# Company already in cache. Skipping.
# Geocoding company "6C's LLC".
# Company already in cache. Skipping.
# Geocoding company "711 GEOL LLC".
# Company already in cache. Skipping.
# Geocoding company "720 Worldwide Inc.".
# Company already in cache. Skipping.
# Geocoding company "845 Design Group, P.C.".
# Company already in cache. Skipping.
# Geocoding company "88 MIKES INC.".
# Company already in cache. Skipping.
# Geocoding company "8th Day Consulting, Training & Software".
# Company already in cache. Skipping.
# Geocoding company "97 Grain & Trucking, LLC".
# Company already in cache. Skipping.
# Geocoding company "@Contract Partners LLC".
# Company already in cache. Skipping.
# Geocoding company "@Veterans Construction Group, LLC.".
# Company already in cache. Skipping.
# Geocoding company "A & B Sanchez Landscaping, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A & D Cartage Inc.".
# Company already in cache. Skipping.
# Geocoding company "A & D Property Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A & G Cleaning Services".
# Company already in cache. Skipping.
# Geocoding company "A & H Mechanical, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A & J GENERAL CONSTRUCTION CO".
# Company already in cache. Skipping.
# Geocoding company "A & L Environmental LLC".
# Company already in cache. Skipping.
# Geocoding company "A & M General Contractor Corporation".
# Company already in cache. Skipping.
# Geocoding company "A & O Enterprises, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A & O Recovery Solutions, LLC.".
# Company already in cache. Skipping.
# Geocoding company "A & R Janitorial Service, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A & S Expert Transportation LLC".
# Company already in cache. Skipping.
# Geocoding company "A & T Trucking Company".
# Company already in cache. Skipping.
# Geocoding company "A AND I MEDICAL TRANSPORTATION INC.".
# Company already in cache. Skipping.
# Geocoding company "A B Petroleum Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A C Gentrol, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A C Hauling Services Inc.".
# Company already in cache. Skipping.
# Geocoding company "A GUIZAR TRUCKING INC".
# Company already in cache. Skipping.
# Geocoding company "A Jacq Hammer, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A M Perez Trucking Company".
# Company already in cache. Skipping.
# Geocoding company "A New Beginning Starts Now LLC".
# Company already in cache. Skipping.
# Geocoding company "A New Way to Go DME Supply Inc.".
# Company already in cache. Skipping.
# Geocoding company "A Perfect Sign, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A R 1 Transport, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A Secure Foundation, LLC".
# Company already in cache. Skipping.
# Geocoding company "A Tip For The Future LLC".
# Company already in cache. Skipping.
# Geocoding company "A Train Transportation".
# Company already in cache. Skipping.
# Geocoding company "A VET Communications, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A View2 ITS, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A WMBE CARPENTRY CONTRACTORS".
# Company already in cache. Skipping.
# Geocoding company "A and C Electric Company, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A&A Consultants, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A&A TRANSPORT SERVICES INC.".
# Company already in cache. Skipping.
# Geocoding company "A&B Environmental Construction Inc.".
# Company already in cache. Skipping.
# Geocoding company "A&R Concrete Construction Company".
# Company already in cache. Skipping.
# Geocoding company "A-1 Haney Plumbing Inc.".
# Company already in cache. Skipping.
# Geocoding company "A-1 Private Investigations, LLC".
# Company already in cache. Skipping.
# Geocoding company "A-FAST BOARD UP & GLASS, INC.".
# Company already in cache. Skipping.
# Geocoding company "A-Masonry Group, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A-Ware Enterprises, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A-Way Training & Tactical, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A. Alva Rosales & Assocs., LTD".
# Company already in cache. Skipping.
# Geocoding company "A. D. Floor Care, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A. J. Rhem & Associates Inc.".
# Company already in cache. Skipping.
# Geocoding company "A. Lavelle Consulting Services Llc".
# Company already in cache. Skipping.
# Geocoding company "A. Lucas & Sons".
# Company already in cache. Skipping.
# Geocoding company "A. Maestranzi Sons Knife Services LLC".
# Company already in cache. Skipping.
# Geocoding company "A. WBE Construction Services, LLC".
# Company already in cache. Skipping.
# Geocoding company "A. Weinstein & Associates".
# Company already in cache. Skipping.
# Geocoding company "A.G. Construction Services Inc.".
# Company already in cache. Skipping.
# Geocoding company "A.H.C. Mechanical Services LLC".
# Company already in cache. Skipping.
# Geocoding company "A.J. Wright And Associates, Ltd.".
# Company already in cache. Skipping.
# Geocoding company "A.L.L. Masonry Construction Co., Inc.".
# Company already in cache. Skipping.
# Geocoding company "A.M. Bus Company".
# Company already in cache. Skipping.
# Geocoding company "A.M.C. Mechanical, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A.S. Cartage, Co.".
# Company already in cache. Skipping.
# Geocoding company "A.S.A.P. Transportation Inc.".
# Company already in cache. Skipping.
# Geocoding company "A/Z Analytical Consulting Services".
# Company already in cache. Skipping.
# Geocoding company "A1PLUSSOFT, INC".
# Company already in cache. Skipping.
# Geocoding company "A2 Landscape Contractors, Inc.".
# Company already in cache. Skipping.
# Geocoding company "A3 Environmental, LLC".
# Company already in cache. Skipping.
# Geocoding company "A9 Consulting Group, LLC".
# Company already in cache. Skipping.
# Geocoding company "AA MEDICAL TRANSPORTATION LIMITED".
# Company already in cache. Skipping.
# Geocoding company "AAA Construction Services, LLC".
# Company already in cache. Skipping.
# Geocoding company "AAA Engineering, Ltd.".
# Company already in cache. Skipping.
# Geocoding company "AAA Home Experts".
# Company already in cache. Skipping.
# Geocoding company "AAA-1 Transportation Inc.".
# Company already in cache. Skipping.
# Geocoding company "AASM Concrete and Aggregate Testing".
# Company already in cache. Skipping.
# Geocoding company "AB Transport & Logistics, Inc.".
# Company already in cache. Skipping.
# Geocoding company "ABAXENT, LLC".
# Company already in cache. Skipping.
# Geocoding company "ABC Engineering LLC".
# Company already in cache. Skipping.
# Geocoding company "ABC Humane Wildlife Control & Prevention, Inc.".
# Company already in cache. Skipping.
# Geocoding company "ABCD Gathering LLC".
# Company already in cache. Skipping.
# Geocoding company "ABI CARTAGE INC".
# Company already in cache. Skipping.
# Geocoding company "ABNA Engineering, Inc.".
# Company already in cache. Skipping.
# Geocoding company "ABNA Of Illinois, Inc.".
# Company already in cache. Skipping.
# Geocoding company "ABOUND EQUITIES, INC.".
# Company already in cache. Skipping.
# Geocoding company "ABT Products & Services LTD".
# Company already in cache. Skipping.
# Geocoding company "AC & DC POWER TECHNOLOGIES, LLC".
# Company already in cache. Skipping.
# Geocoding company "AC Dillard LLC".
# Company already in cache. Skipping.
# Geocoding company "AC IRON, LLC".
# Company already in cache. Skipping.
# Geocoding company "AC Research Inc.".
# Company already in cache. Skipping.
# Geocoding company "ACD Services Inc".
# Company already in cache. Skipping.
# Geocoding company "ACE SUPPLY CORP".
# Company already in cache. Skipping.
# Geocoding company "ACEAPPLICATIONS, LLC".
# Company already in cache. Skipping.
# Geocoding company "ACJ Partners, LLC".
# Company already in cache. Skipping.
# Geocoding company "ACOT Associates Group, LLC".
# Company already in cache. Skipping.
# Geocoding company "ADELFIA LLC".
# Company already in cache. Skipping.
# Geocoding company "ADOBE MASONRY LLC".
# Company already in cache. Skipping.
# Geocoding company "ADS System Safety Consulting, LLC".
# Company already in cache. Skipping.
# Geocoding company "ADV Builders, Inc.".
# Company already in cache. Skipping.
# Geocoding company "ADVANCE SECURITY RESOURCES LLC.".
# Company already in cache. Skipping.
# Geocoding company "ADVANCED RELOCATOR'S INC.dba THE LOVELACE GROUP, INC.".
# Company already in cache. Skipping.
# Geocoding company "AE COMPUTERS, LTD".
# Company already in cache. Skipping.
# Geocoding company "AEP Group LLC".
# Company already in cache. Skipping.
# Geocoding company "AFABLE ACCOUNTING & COMPUTER SERVICES LLC".
# Company already in cache. Skipping.
# Geocoding company "AFE Construction, LLC".
# Company already in cache. Skipping.
# Geocoding company "AFFIRMING VOICES".
# Company already in cache. Skipping.
# Geocoding company "AFO Technology Group, LLC".
# Company already in cache. Skipping.
# Geocoding company "AG Construction, Inc.".
# Company already in cache. Skipping.
# Geocoding company "AGB Investigative Services, Incorporated".
# Company already in cache. Skipping.
# Geocoding company "AGEATIA TECHNOLOGY CONSULTANCY SERVICES INC".
# Company already in cache. Skipping.
# Geocoding company "AGG Consulting, Inc.".
# Company already in cache. Skipping.
# Geocoding company "AGPD Paving, LLC".
# Company already in cache. Skipping.
# Geocoding company "AH Global Services LLC".
# Company already in cache. Skipping.
# Geocoding company "AIA Technologies, LLC".
# Company already in cache. Skipping.
# Geocoding company "AIC Material and Supply LLC".
# Company already in cache. Skipping.
# Geocoding company "AIEPA: Advocate and Instructional Expert for People with Autism, LLC".
# Company already in cache. Skipping.
# Geocoding company "AIRPORT DESIGN CONSULTANTS, INC.".
# Company already in cache. Skipping.
# Geocoding company "AJ Trucking, LLC".
# Company already in cache. Skipping.
# Geocoding company "AJ&M Demolition Inc".
# Company already in cache. Skipping.
# Geocoding company "AKA Comp Solutions, Inc.".
# Company already in cache. Skipping.
# Geocoding company "AKAM - Construction Rehabing Demolition Company".
# Company already in cache. Skipping.
# Geocoding company "AKORBI LANGUAGE SERVICES LLC".
# Company already in cache. Skipping.
# Geocoding company "ALAS TRUCKING, INC.".
# Company already in cache. Skipping.
# Geocoding company "ALC Enterprises Inc".
# Company already in cache. Skipping.
# Geocoding company "ALEGNA INC.".
# Company already in cache. Skipping.
# Geocoding company "ALF Cartage Inc.".
# Company already in cache. Skipping.
# Geocoding company "ALIA Drug Testing, LLC".
# Company already in cache. Skipping.
# Geocoding company "ALIS Consulting Services LLC".
# Company already in cache. Skipping.
# Geocoding company "ALL CLEAN CONSTRUCTION SERVICES INC.".
# Company already in cache. Skipping.
# Geocoding company "ALL-PRO HEATING, AIR CONDITIONING & PLUMBING, LLC".
# Company already in cache. Skipping.
# Geocoding company "ALMIGHTY 1 LITTLE HELPERS TRANSPORTATION INC".
# Company already in cache. Skipping.
# Geocoding company "ALO Engineering, Inc.".
# Company already in cache. Skipping.
# Geocoding company "ALPETUS LLC".
# Company already in cache. Skipping.
# Geocoding company "ALPHA AMERICAN MEDICAL SUPPLY PROFESSIONAL LIMITED LIABILITY COMPANY".
# Company already in cache. Skipping.
# Geocoding company "ALPHA ELECTRICAL SERVICES LLC".
# Company already in cache. Skipping.
# Geocoding company "ALPHA FIRE SPRINKLER COMPANY LLC".
# Company already in cache. Skipping.
# Geocoding company "ALPHA OMEGA SYSTEMS CORPORATION".
# Company already in cache. Skipping.
# Geocoding company "ALPHA POWER GROUP. LLC".
# Company already in cache. Skipping.
# Geocoding company "ALR DIVERSIFIED SUPPLY CHAIN MANAGEMENT LLC".
# Company already in cache. Skipping.
# Geocoding company "ALT-Enter, LLC".
# Company already in cache. Skipping.
# Geocoding company "AMALGAMATED SERVICES, INC.".
# Company already in cache. Skipping.
# Geocoding company "AMB Renewable Energy Inc".
# Company already in cache. Skipping.
# Geocoding company "AMERICAN ENGINEERING CONSULTANTS, INC.".
# Company already in cache. Skipping.
# Geocoding company "AMERICAN TRUCK SERVICE ENTERPRISES INC.".
# Company already in cache. Skipping.
# Geocoding company "AMERICAN VETERAN ENGINEERING, LLC".
# Company already in cache. Skipping.
# Geocoding company "AMEROC Export Inc.".
# Company already in cache. Skipping.
# Geocoding company "AMES Engineering, Inc.".
# Company already in cache. Skipping.
# Geocoding company "AMF Specialists LLC".
# Company already in cache. Skipping.
# Geocoding company "AMS Elite Solutions, Inc.".
# Company already in cache. Skipping.
# Geocoding company "ANALI TRUCKING INC".
# Company already in cache. Skipping.
# Geocoding company "ANC Midwest LLC".
# Company already in cache. Skipping.
# Geocoding company "ANCOMEX, LLC".
# Company already in cache. Skipping.
# Geocoding company "ANTOINETTE MITCHELL CONSULTING LLC".
# Company already in cache. Skipping.
# Geocoding company "ANZ Solutions LLC".
# Company already in cache. Skipping.
# Geocoding company "ANick Energy Services LLC".
# Company already in cache. Skipping.
# Geocoding company "AP Private Detective & Security Agency Ltd.".
# Company already in cache. Skipping.
# Geocoding company "APEX Direct, Inc.".
# Company already in cache. Skipping.
# Geocoding company "APMonarch PLLC".
# Company already in cache. Skipping.
# Geocoding company "APPLIED REAL ESTATE ANALYSIS, INC.".
# Company already in cache. Skipping.
# Geocoding company "APS Consulting, Inc.".
# Company already in cache. Skipping.
# Geocoding company "APTUDE, INC.".
# Company already in cache. Skipping.
# Geocoding company "AQL Technologies Inc.".
# Company already in cache. Skipping.
# Geocoding company "AR Professional Property Preservation, Inc.".
# Company already in cache. Skipping.
# Geocoding company "ARC Alternative and Renewable Construction LLC".
# Company already in cache. Skipping.
# Geocoding company "ARCH EQUIPMENT GROUP LLC".
# Company already in cache. Skipping.
# Geocoding company "ARF Food Safety Consulting Group".
# Company already in cache. Skipping.
# Geocoding company "ARK Engineering Associates, Ltd.".
# Company already in cache. Skipping.
# Geocoding company "ARLINGTON RESOURCES, INC.".
# Company already in cache. Skipping.
# Geocoding company "ARQ, LLC".
# Company already in cache. Skipping.
# Geocoding company "ARTS WIRED ELECTRONICS, LLC".
# Company already in cache. Skipping.
# Geocoding company "ASA Law Group LLC".
# Company already in cache. Skipping.
# Geocoding company "ASAF, Inc.".
# Company already in cache. Skipping.
# Geocoding company "ASC Group, Inc.".
# Company already in cache. Skipping.
# Geocoding company "ASC Health, LLC".
# Company already in cache. Skipping.
# Geocoding company "ASC Insulation, Fireproofing, and Supplies Inc.".
# Company already in cache. Skipping.
# Geocoding company "ASC Window Corporation".
# Company already in cache. Skipping.
# Geocoding company "ASERET DEVELOPMENT CARPENTRY SERVICES,LLC".
# Company already in cache. Skipping.
# Geocoding company "ASIL Ventures, LLC".
# Company already in cache. Skipping.
# Geocoding company "ASM Consultants, Inc.".
# Company already in cache. Skipping.
# Geocoding company "ASP Industries, Inc".
# Company already in cache. Skipping.
# Geocoding company "ASSEMBLE DESIGN WORKSHOP PLLC".
# Company already in cache. Skipping.
# Geocoding company "ASSET ENGINEERING INC".
# Company already in cache. Skipping.
# Geocoding company "ASTRI LLC".
# Company already in cache. Skipping.
# Geocoding company "ATLANTIC PAINTING CO.,INC.".
# Company already in cache. Skipping.
# Geocoding company "ATU Cartage, Inc.".
# Company already in cache. Skipping.
# Geocoding company "ATW HEALTH SOLUTIONS INC.".
# Company already in cache. Skipping.
# Geocoding company "AUNTIE VEE'S, INC.".
# Company already in cache. Skipping.
# Geocoding company "AV Construction Consulting Corporation".
# Company already in cache. Skipping.
# Geocoding company "AV Media Pros".
# Company already in cache. Skipping.
# Geocoding company "AYO Foods".
# Company already in cache. Skipping.
# Geocoding company "Aaron Bros Moving System, Inc".
# Company already in cache. Skipping.
# Geocoding company "Aaron Engineering Services".
# Company already in cache. Skipping.
# Geocoding company "Abari Construction, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Abatement Materials, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Abator Information Services Inc".
# Company already in cache. Skipping.
# Geocoding company "Abbott Connection, Ltd.".
# Company already in cache. Skipping.
# Geocoding company "Abbott Industries, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Abby Supply, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Abitua Sewer, Water & Plumbing Inc.".
# Company already in cache. Skipping.
# Geocoding company "Above the Rest Drone Services, inc.".
# Company already in cache. Skipping.
# Geocoding company "Absolute Informatics Inc".
# Company already in cache. Skipping.
# Geocoding company "Absolute Staffing & Consulting Solutions, LLC".
# Company already in cache. Skipping.
# Geocoding company "Absolutely Anything Essential, LLC".
# Company already in cache. Skipping.
# Geocoding company "Abundance Of Care Healthcare Staffing Agency LLC".
# Company already in cache. Skipping.
# Geocoding company "Acacia Financial Group, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Acamard Technologies, Inc".
# Company already in cache. Skipping.
# Geocoding company "Accede Solutions Inc".
# Company already in cache. Skipping.
# Geocoding company "Accel Construction Services Group, LLC".
# Company already in cache. Skipping.
# Geocoding company "Accelar Group LLC".
# Company already in cache. Skipping.
# Geocoding company "Accent Landscape Design, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Accent Marketing, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Accent Urban Design, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Access Control Company, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Access Engineering, LLC.".
# Company already in cache. Skipping.
# Geocoding company "Access Therapies, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Accessology Too, LLC".
# Company already in cache. Skipping.
# Geocoding company "Acclaim Collier Engineering, LLC".
# Company already in cache. Skipping.
# Geocoding company "Accorn Granite & Natural Stone, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Accredited Construction Material Testing Laboratory, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Accugen laboratories, inc".
# Company already in cache. Skipping.
# Geocoding company "Accurate Biometrics, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Accurate Construction Site Services".
# Company already in cache. Skipping.
# Geocoding company "Accurate Data, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Accurate Die Cutting, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Accurate Environmental Solutions, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Accurate Group, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Accuvoice, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ace Fire Protection LLC".
# Company already in cache. Skipping.
# Geocoding company "Ace Petroleum, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ace Restaurant Equipment & Supplies".
# Company already in cache. Skipping.
# Geocoding company "Ace Restoration Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ace Staffing LLC".
# Company already in cache. Skipping.
# Geocoding company "Acento Advertising, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Acextic Corporation".
# Company already in cache. Skipping.
# Geocoding company "Aclara Research LLC".
# Company already in cache. Skipping.
# Geocoding company "Acosta's Transport Inc".
# Company already in cache. Skipping.
# Geocoding company "AcrossTech, Inc".
# Company already in cache. Skipping.
# Geocoding company "Action Advertising Inc.".
# Company already in cache. Skipping.
# Geocoding company "Action Bag Company".
# Company already in cache. Skipping.
# Geocoding company "Action Group MGMT, LLC".
# Company already in cache. Skipping.
# Geocoding company "Action Painting Co., Inc.".
# Company already in cache. Skipping.
# Geocoding company "Active Cyber, LLC".
# Company already in cache. Skipping.
# Geocoding company "Active Electrical Supply Company".
# Company already in cache. Skipping.
# Geocoding company "Active Office Solution".
# Company already in cache. Skipping.
# Geocoding company "Actuarial Factor LLC".
# Company already in cache. Skipping.
# Geocoding company "Acumen Building Enterprise, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Acura Inc.".
# Company already in cache. Skipping.
# Geocoding company "Acustom Transport Services LLC".
# Company already in cache. Skipping.
# Geocoding company "AdCo Advertising Agency, Inc".
# Company already in cache. Skipping.
# Geocoding company "Ada S. McKinley Community Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Adams Painting Co".
# Company already in cache. Skipping.
# Geocoding company "Adams, Howard & Mathews Associates, LLC".
# Company already in cache. Skipping.
# Geocoding company "Added Dimension, LLC".
# Company already in cache. Skipping.
# Geocoding company "Addison Electric Inc.".
# Company already in cache. Skipping.
# Geocoding company "Adelante Construction Group LLC".
# Company already in cache. Skipping.
# Geocoding company "Adelante, P.C.".
# Company already in cache. Skipping.
# Geocoding company "Adept Flooring LLC".
# Company already in cache. Skipping.
# Geocoding company "Administrative Resolutions Network, LLC".
# Company already in cache. Skipping.
# Geocoding company "Adnama, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Adrenaline Special Events LLC".
# Company already in cache. Skipping.
# Geocoding company "Adrian Onates Trucking Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Adriatica Construction Company".
# Company already in cache. Skipping.
# Geocoding company "Advance Analytical Solutions, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Advance Electronic & Computer, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Advanced Care Services, Inc".
# Company already in cache. Skipping.
# Geocoding company "Advanced Contractor Solutions, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Advanced Integration Group, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Advanced Partners, LLC.".
# Company already in cache. Skipping.
# Geocoding company "Advanced Systems Consultant, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Advanced Water Solutions, LLC".
# Company already in cache. Skipping.
# Geocoding company "Advanced Womens Healthcare S.C.".
# Company already in cache. Skipping.
# Geocoding company "Advantage Brokerage Corporation".
# Company already in cache. Skipping.
# Geocoding company "Advantage Business Systems, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Advantage Global Logistics Corp".
# Company already in cache. Skipping.
# Geocoding company "Advantage Marketing Group, Ltd".
# Company already in cache. Skipping.
# Geocoding company "Advent Business Company Inc".
# Company already in cache. Skipping.
# Geocoding company "Advize Health LLC".
# Company already in cache. Skipping.
# Geocoding company "Aerapy, LLC".
# Company already in cache. Skipping.
# Geocoding company "Aetso Inc.".
# Company already in cache. Skipping.
# Geocoding company "Affinity Patient Coordination LLC".
# Company already in cache. Skipping.
# Geocoding company "Affinity Pharmacy Care, LLC".
# Company already in cache. Skipping.
# Geocoding company "Affluent Solutions, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Affordable Onboarding, LLC".
# Company already in cache. Skipping.
# Geocoding company "Affordable Pressure Washing Cicero Illinois LLC".
# Company already in cache. Skipping.
# Geocoding company "Afton Partners, LLC".
# Company already in cache. Skipping.
# Geocoding company "Agency Landscape + Planning".
# Company already in cache. Skipping.
# Geocoding company "Aggrecon Crushing & Recycling, LLC".
# Company already in cache. Skipping.
# Geocoding company "Aggressive Plumbing Systems, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Agile Construction Services, LLC".
# Company already in cache. Skipping.
# Geocoding company "Agile N2N, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Agile Procurement & Consulting Services, LLC".
# Company already in cache. Skipping.
# Geocoding company "Agilite, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Agua Plumbing, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Aguirre Project Resources LLC".
# Company already in cache. Skipping.
# Geocoding company "Ahava Services, LLC".
# Company already in cache. Skipping.
# Geocoding company "Ahimsa Consulting, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ahmed & Harvell, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ahmed Associates, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ahrens Contracting, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Air & Wellness Safety Training Company".
# Company already in cache. Skipping.
# Geocoding company "Air Design Systems, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Air Supply Air Conditioning & Heating, Inc.".
# Company already in cache. Skipping.
# Geocoding company "AirWorks Concessions and ConRac Supplies LLC".
# Company already in cache. Skipping.
# Geocoding company "Airah Services Group LLC".
# Company already in cache. Skipping.
# Geocoding company "Airmac LLC".
# Company already in cache. Skipping.
# Geocoding company "Airport Edge, LLC".
# Company already in cache. Skipping.
# Geocoding company "Airy's, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Airzone Heating & Cooling".
# Company already in cache. Skipping.
# Geocoding company "Ajenda Interactive Media, LLC".
# Company already in cache. Skipping.
# Geocoding company "Akan Mechanical, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Akil-Abree Consulting LLC".
# Company already in cache. Skipping.
# Geocoding company "Akins Medical Transportation Company".
# Company already in cache. Skipping.
# Geocoding company "Albert Whitehead, P.C.".
# Company already in cache. Skipping.
# Geocoding company "Aldevra, LLC".
# Company already in cache. Skipping.
# Geocoding company "Aleman Studio LLC".
# Company already in cache. Skipping.
# Geocoding company "Alepho Capital LLC".
# Company already in cache. Skipping.
# Geocoding company "Alert IT Solutions Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alexander Brothers Construction Corporation".
# Company already in cache. Skipping.
# Geocoding company "Alexander Construction Group, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alexis Lybrook Taubert, Phd., Ltd.".
# Company already in cache. Skipping.
# Geocoding company "Alexis Of Illinois INC.".
# Company already in cache. Skipping.
# Geocoding company "Alexis P. Transport Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alfa Chicago Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alfredo's Iron Works Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alicia International, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Align Consulting and Management LLC".
# Company already in cache. Skipping.
# Geocoding company "Alise Lux LLC".
# Company already in cache. Skipping.
# Geocoding company "Alison Jannotta and Associates, Inc.".
# Company already in cache. Skipping.
# Geocoding company "All American Paper Co.".
# Company already in cache. Skipping.
# Geocoding company "All Around Construction and Remodeling LLC".
# Company already in cache. Skipping.
# Geocoding company "All Carpentry Concepts, Inc".
# Company already in cache. Skipping.
# Geocoding company "All Chicago, Inc.".
# Company already in cache. Skipping.
# Geocoding company "All Environmental Safety Corp".
# Company already in cache. Skipping.
# Geocoding company "All Girls Transportation & Logistics, Inc.".
# Company already in cache. Skipping.
# Geocoding company "All In One Management and Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "All J Steel Inc.".
# Company already in cache. Skipping.
# Geocoding company "All Pests Controlled, Inc.".
# Company already in cache. Skipping.
# Geocoding company "All Tech Energy, Inc.".
# Company already in cache. Skipping.
# Geocoding company "All Time Wrecking & Hauling, Inc.".
# Company already in cache. Skipping.
# Geocoding company "All Together".
# Company already in cache. Skipping.
# Geocoding company "All Weather Specialist Inc.".
# Company already in cache. Skipping.
# Geocoding company "All-Pro Placement Service, Inc.".
# Company already in cache. Skipping.
# Geocoding company "All-Wall Coatings LLC".
# Company already in cache. Skipping.
# Geocoding company "AllKinds Studio Inc.".
# Company already in cache. Skipping.
# Geocoding company "AllSource Construction Supply".
# Company already in cache. Skipping.
# Geocoding company "Allaso Performance Solutions, Inc".
# Company already in cache. Skipping.
# Geocoding company "Allcare Discount Pharmacy Inc.".
# Company already in cache. Skipping.
# Geocoding company "Allen + Shariff Corporation".
# Company already in cache. Skipping.
# Geocoding company "Allen Prestwood Concrete Construction INC".
# Company already in cache. Skipping.
# Geocoding company "Alliance Allied Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alliance Companies, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Allied Safety Group, LLC".
# Company already in cache. Skipping.
# Geocoding company "Allied Services Group, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alligator Computer Systems, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Allize LLC".
# Company already in cache. Skipping.
# Geocoding company "Allpoints Security and Detective, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Allport Construction Corporation".
# Company already in cache. Skipping.
# Geocoding company "Allstate Concrete Cutting, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Allure Laser & Med Spa, LLC".
# Company already in cache. Skipping.
# Geocoding company "Ally Construction, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alma Advisory Group, LLC".
# Company already in cache. Skipping.
# Geocoding company "Almaraz Trucking Inc.".
# Company already in cache. Skipping.
# Geocoding company "Aloha Document Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alonzo Trucking Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alpha Omega Pest Elimination Corporation".
# Company already in cache. Skipping.
# Geocoding company "Alpha Phase Electric LLC".
# Company already in cache. Skipping.
# Geocoding company "Alpha Prime Wireless Communications, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alpine Demolition Services, LLC".
# Company already in cache. Skipping.
# Geocoding company "Alpine Engineering Services, LLC".
# Company already in cache. Skipping.
# Geocoding company "Alrek Business Solutions, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alron Electric, Incorporated".
# Company already in cache. Skipping.
# Geocoding company "Alta Linc, Inc".
# Company already in cache. Skipping.
# Geocoding company "AltaStaff, LLC".
# Company already in cache. Skipping.
# Geocoding company "Altech Services Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alternatives Counseling, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Altra Builders, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Altusworks, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alvarez, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Alzate, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Amalgamated Endeavors Incorporated".
# Company already in cache. Skipping.
# Geocoding company "Amalgamated Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Amanda's Dependable Services Inc.".
# Company already in cache. Skipping.
# Geocoding company "Amazing Edibles LTD.".
# Company already in cache. Skipping.
# Geocoding company "Amazing Grace Medical Services".
# Company already in cache. Skipping.
# Geocoding company "Ambar, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Amber S. Hendley LLC".
# Company already in cache. Skipping.
# Geocoding company "Amberleaf Cabinetry Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ambika Pharmacy, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ambri, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ambriosal LLC".
# Company already in cache. Skipping.
# Geocoding company "AmeTrade, Inc.".
# Company already in cache. Skipping.
# Geocoding company "America Environmental Construction Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Asbestos Abatement, LLC".
# Company already in cache. Skipping.
# Geocoding company "American Asphalt Surface Recycling, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Color Labs, Inc".
# Company already in cache. Skipping.
# Geocoding company "American Concrete Restorations, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Construction Supplies, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Courier Service, Incorporated".
# Company already in cache. Skipping.
# Geocoding company "American Erosion Control Solutions, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Exterior-Interior Services, Incorporated".
# Company already in cache. Skipping.
# Geocoding company "American Filing Solutions inc".
# Company already in cache. Skipping.
# Geocoding company "American First Contracting, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Floor Company, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Heritage Supplies, Ltd".
# Company already in cache. Skipping.
# Geocoding company "American Igloo Builders, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Infrastructure Technologies, LLC".
# Company already in cache. Skipping.
# Geocoding company "American Institute of Computers, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Insulation, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Kitchen Delights, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Landscaping, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Maintenance & Carpet Cleaning LLC".
# Company already in cache. Skipping.
# Geocoding company "American Marketing Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Minority Business Forms, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Packaging I, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Precision Supply, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Resource Solutions, Inc".
# Company already in cache. Skipping.
# Geocoding company "American Steel Fabricators, Inc.".
# Company already in cache. Skipping.
# Geocoding company "American Surveying & Engineering, P.C.".
# Company already in cache. Skipping.
# Geocoding company "American Telephone Technology Incorporated".
# Company already in cache. Skipping.
# Geocoding company "American Veteran Industries, LLC".
# Company already in cache. Skipping.
# Geocoding company "American Veterans Construction, LLC".
# Company already in cache. Skipping.
# Geocoding company "American mechanical services group llc.".
# Company already in cache. Skipping.
# Geocoding company "Americloud Solutions, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Americo Industrial Supply Inc".
# Company already in cache. Skipping.
# Geocoding company "Ameridial, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Amerigo, LLC".
# Company already in cache. Skipping.
# Geocoding company "Amistad Enterprises, inc.".
# Company already in cache. Skipping.
# Geocoding company "Ammons Transportation Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "AmorServ LLC".
# Company already in cache. Skipping.
# Geocoding company "Ampere Electric Company".
# Company already in cache. Skipping.
# Geocoding company "Amzo Zip Mailing Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Anamco Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Anarkie Construction Services, LLC".
# Company already in cache. Skipping.
# Geocoding company "Anchor Data Systems, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Anchor Staffing Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ancora Associates, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Andersen Concrete Pumping & Equipment Rental, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Anderson & Shah Roofing, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Anderson Blinds, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Anderson Environmental Co".
# Company already in cache. Skipping.
# Geocoding company "Anderson Lock Company, Ltd".
# Company already in cache. Skipping.
# Geocoding company "Anderson Paint Store LLC".
# Company already in cache. Skipping.
# Geocoding company "Andes Capital Group, LLC".
# Company already in cache. Skipping.
# Geocoding company "Andrea McNeil, LLC".
# Company already in cache. Skipping.
# Geocoding company "Andrews Printing, LLC".
# Company already in cache. Skipping.
# Geocoding company "Anello Data Solutions LLC".
# Company already in cache. Skipping.
# Geocoding company "Anelster Incorporated".
# Company already in cache. Skipping.
# Geocoding company "Angel Cleaning Service of Illinois Inc.".
# Company already in cache. Skipping.
# Geocoding company "AngelFlight Marketing Service Inc.".
# Company already in cache. Skipping.
# Geocoding company "Angela R Mathews Consulting, LLC".
# Company already in cache. Skipping.
# Geocoding company "Angelics Heavenly Transportation LLC".
# Company already in cache. Skipping.
# Geocoding company "Angelo Construction Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Angstrom LLC".
# Company already in cache. Skipping.
# Geocoding company "Anibere Beauty".
# Company already in cache. Skipping.
# Geocoding company "Ann Dana Consulting LLC".
# Company already in cache. Skipping.
# Geocoding company "Ann L. Schneider and Associates, LLC".
# Company already in cache. Skipping.
# Geocoding company "Anna J. Carvalho, Consultant LLC".
# Company already in cache. Skipping.
# Geocoding company "Anne Kustner Lighting Design, Ltd.".
# Company already in cache. Skipping.
# Geocoding company "Anneshia Freeman and Associates Consulting Services, LLC".
# Company already in cache. Skipping.
# Geocoding company "Anointed & Appointed Accounting Services Inc.".
# Company already in cache. Skipping.
# Geocoding company "Answers Lie Within, INC".
# Company already in cache. Skipping.
# Geocoding company "Antares Computer Systems Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ante Up Construction".
# Company already in cache. Skipping.
# Geocoding company "Anthem Excavation & Demolition Inc.".
# Company already in cache. Skipping.
# Geocoding company "Antigua, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Anuco Rx".
# Company already in cache. Skipping.
# Geocoding company "Any Temperature Co., Inc.".
# Company already in cache. Skipping.
# Geocoding company "Anzy Supply, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Aoba Enterprises, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Apache Service and Supply Co.".
# Company already in cache. Skipping.
# Geocoding company "Apex Business Solutions & Development, LLC".
# Company already in cache. Skipping.
# Geocoding company "Apex Consulting Engineers, L.L.C.".
# Company already in cache. Skipping.
# Geocoding company "Apex Cybersecurity Solutions Inc.".
# Company already in cache. Skipping.
# Geocoding company "Apex Elevator Company, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Apex LED Solutions, LLC".
# Company already in cache. Skipping.
# Geocoding company "Apia Consulting LLC".
# Company already in cache. Skipping.
# Geocoding company "Apple Designs, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Applied Controls & Contracting Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Appreciation Corporation".
# Company already in cache. Skipping.
# Geocoding company "Approved Flooring Investments, Inc".
# Company already in cache. Skipping.
# Geocoding company "April Building Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "April-Cobra Enterprises, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Aqua Vitae Engineering, LLC".
# Company already in cache. Skipping.
# Geocoding company "Aqualyze, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Aquas, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Araiza Corporation".
# Company already in cache. Skipping.
# Geocoding company "Arambula Trucking Inc.".
# Company already in cache. Skipping.
# Geocoding company "Arc net elevator services LLC".
# Company already in cache. Skipping.
# Geocoding company "Arch Angel Services, Corp.".
# Company already in cache. Skipping.
# Geocoding company "Archaeology and Geomorphology Services".
# Company already in cache. Skipping.
# Geocoding company "Archer Street LLC".
# Company already in cache. Skipping.
# Geocoding company "ArchiTech Consulting, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Architechnician Construction Solutions".
# Company already in cache. Skipping.
# Geocoding company "Architectonic Solutions, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Architectural Design Group, Inc".
# Company already in cache. Skipping.
# Geocoding company "Architectural Fixtures, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Architectural Services  Group, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Architrave, Ltd.".
# Company already in cache. Skipping.
# Geocoding company "Archon Construction Co., Inc.".
# Company already in cache. Skipping.
# Geocoding company "Arco Trucking, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Arcorp Structures, LLC".
# Company already in cache. Skipping.
# Geocoding company "Arcos Environmental Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Arcturis, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Area Equipment, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Areatha Construction Co., Inc.".
# Company already in cache. Skipping.
# Geocoding company "Arem Container & Supply Co.".
# Company already in cache. Skipping.
# Geocoding company "Arete' Healthcare Group, LLC".
# Company already in cache. Skipping.
# Geocoding company "Arga Investment Management, LP".
# Company already in cache. Skipping.
# Geocoding company "Argo Construction, LLC".
# Company already in cache. Skipping.
# Geocoding company "Arias Information Solutions, LLC".
# Company already in cache. Skipping.
# Geocoding company "Aries Charter Transportation, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ariyon LLC".
# Company already in cache. Skipping.
# Geocoding company "Armand Resource Group, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Armando's Landscape Services Inc.".
# Company already in cache. Skipping.
# Geocoding company "Armas Painting LLC".
# Company already in cache. Skipping.
# Geocoding company "Armor Materials, LLC".
# Company already in cache. Skipping.
# Geocoding company "Armor Sealing LLC".
# Company already in cache. Skipping.
# Geocoding company "Array Technical Service Group-ATSG".
# Company already in cache. Skipping.
# ...
# Company already in cache. Skipping.
# Geocoding company "Rishi Pharmacy, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Risk & Insurance Management Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Risk Management Solutions of America, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Risk Management and Information Systems, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Riteway-Huggins Construction, Inc".
# Company already in cache. Skipping.
# Geocoding company "Ritland Holdings, LLC".
# Company already in cache. Skipping.
# Geocoding company "Rivetna Architects, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Riya Interactive Inc".
# Company already in cache. Skipping.
# Geocoding company "RmBowie Incorporated".
# Company already in cache. Skipping.
# Geocoding company "Ro Pro Electric Co. Inc".
# Company already in cache. Skipping.
# Geocoding company "Road & Sons, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Roadway Lines Corp".
# Company already in cache. Skipping.
# Geocoding company "Roadworks LLC".
# Company already in cache. Skipping.
# Geocoding company "Robert L. Fisher Enterprises TK Electric, LLC".
# Company already in cache. Skipping.
# Geocoding company "Robert L. Miller & Associates Inc".
# Company already in cache. Skipping.
# Geocoding company "Robert W. Hendricksen Company".
# Company already in cache. Skipping.
# Geocoding company "Robert Yiu Construction, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Robin Dee Enterprises, Inc".
# Company already in cache. Skipping.
# Geocoding company "Robinson Hill".
# Company already in cache. Skipping.
# Geocoding company "Robinson's No. 1 Rib, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Robyn Shapiro Design, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Roc Star Studio".
# Company already in cache. Skipping.
# Geocoding company "Rocha Electric Company".
# Company already in cache. Skipping.
# Geocoding company "Rocha Plumbing, Incorporated".
# Company already in cache. Skipping.
# Geocoding company "Rock River Temporary Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Rock Solid Logistics LLC".
# Company already in cache. Skipping.
# Geocoding company "Rock Valley Concrete Cutting, LLC".
# Company already in cache. Skipping.
# Geocoding company "Rocket Crane Services".
# Company already in cache. Skipping.
# Geocoding company "Rocket Productions, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Rocky Hollow Inc.".
# Company already in cache. Skipping.
# Geocoding company "Rodgers Construction Corporation".
# Company already in cache. Skipping.
# Geocoding company "Rodriguez Media Communications, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Rodriguez and Associates, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Roeper Events, LLC".
# Company already in cache. Skipping.
# Geocoding company "Rogan's Country Pharmacy".
# Company already in cache. Skipping.
# Geocoding company "Rogelio Casas Inc.".
# Company already in cache. Skipping.
# Geocoding company "Rogers Contracting Solutions Inc.".
# Company already in cache. Skipping.
# Geocoding company "Rogers Park Geographics LLC".
# Company already in cache. Skipping.
# Geocoding company "Rolei Financial Services Corporation".
# Company already in cache. Skipping.
# Geocoding company "Rome's Joy Catering, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Romero Steel Company, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Romine Commercial Painting, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ron Clesen's Ornamental Plants, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Roof Top Sedums, LLC".
# Company already in cache. Skipping.
# Geocoding company "Rooftopia, LLC".
# Company already in cache. Skipping.
# Geocoding company "RooksDM LLC".
# Company already in cache. Skipping.
# Geocoding company "Rose Gold Rose, LLC".
# Company already in cache. Skipping.
# Geocoding company "Rosemont Logistics Inc".
# Company already in cache. Skipping.
# Geocoding company "Rosno Corp.".
# Company already in cache. Skipping.
# Geocoding company "Ross Barney Architects, P.C.".
# Company already in cache. Skipping.
# Geocoding company "Roth Print Management".
# Company already in cache. Skipping.
# Geocoding company "Roughneck Concrete Drilling & Sawing Co., Inc.".
# Company already in cache. Skipping.
# Geocoding company "Round the clock.home.improvements".
# Company already in cache. Skipping.
# Geocoding company "Rowan International LLC".
# Company already in cache. Skipping.
# Geocoding company "Rowe Intermedia Inc.".
# Company already in cache. Skipping.
# Geocoding company "Roy Keith Electric Company".
# Company already in cache. Skipping.
# Geocoding company "Roy's Paving & Sealcoating Co.".
# Company already in cache. Skipping.
# Geocoding company "Royal Cartage Inc".
# Company already in cache. Skipping.
# Geocoding company "Royal Crane Service, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Royal Crest Realty, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Royal Cyber Inc".
# Company already in cache. Skipping.
# Geocoding company "Royal Pest Elimination LLC.".
# Company already in cache. Skipping.
# Geocoding company "Royal Roots Global Inc.".
# Company already in cache. Skipping.
# Geocoding company "Royal Sheet Metal".
# Company already in cache. Skipping.
# Geocoding company "RoyalT Cleaning Service, LLC".
# Company already in cache. Skipping.
# Geocoding company "Rozco Landscaping Co.".
# Company already in cache. Skipping.
# Geocoding company "Ruben Ortiz Limited".
# Company already in cache. Skipping.
# Geocoding company "Rubino Engineering, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Rubinos & Mesia Engineers, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Rubiostudios Inc.".
# Company already in cache. Skipping.
# Geocoding company "Rudd Resources LLC".
# Company already in cache. Skipping.
# Geocoding company "Ruff Framing Inc".
# Company already in cache. Skipping.
# Geocoding company "Ruiz Construction Co.".
# Company already in cache. Skipping.
# Geocoding company "Ruiz Construction Systems, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ruizscape Construction Inc.".
# Company already in cache. Skipping.
# Geocoding company "Rulas Enterprises Company".
# Company already in cache. Skipping.
# Geocoding company "Runco Office Supplies Equipment Company".
# Company already in cache. Skipping.
# Geocoding company "Russell Electric Contracting, LLC".
# Company already in cache. Skipping.
# Geocoding company "Ryan's Cleaning Services,Inc.".
# Company already in cache. Skipping.
# Geocoding company "Ryan's Plumbing 1 Inc".
# Company already in cache. Skipping.
# Geocoding company "S & D Cartage Inc".
# Company already in cache. Skipping.
# Geocoding company "S & F Software Solutions Inc.".
# Company already in cache. Skipping.
# Geocoding company "S & G Communications, Inc.".
# Company already in cache. Skipping.
# Geocoding company "S & J Construction Co., Inc.".
# Company already in cache. Skipping.
# Geocoding company "S & M Group, Inc.".
# Company already in cache. Skipping.
# Geocoding company "S & M PLOW CORP.".
# Company already in cache. Skipping.
# Geocoding company "S J B Promotions, Inc.".
# Company already in cache. Skipping.
# Geocoding company "S R International Inc.".
# Company already in cache. Skipping.
# Geocoding company "S&S EXPRESS INC".
# Company already in cache. Skipping.
# Geocoding company "S. Medina & Son Landscaping Inc.".
# Company already in cache. Skipping.
# Geocoding company "S. Reynaga Construction Company".
# Company already in cache. Skipping.
# Geocoding company "S.A.I.D. STRATEGY GROUP INCORPORATED".
# Company already in cache. Skipping.
# Geocoding company "S.A.J. Trucking Inc.".
# Company already in cache. Skipping.
# Geocoding company "S.A.L. Express, Inc.".
# Company already in cache. Skipping.
# Geocoding company "S.A.M. Consultants, Inc.".
# Company already in cache. Skipping.
# Geocoding company "S.B. Enterprises, Ltd.".
# Company already in cache. Skipping.
# Geocoding company "S.E.4. Trucking Inc".
# Company already in cache. Skipping.
# Geocoding company "S.G.L. TRUCKING INC".
# Company already in cache. Skipping.
# Geocoding company "S.I.R. Trucking, Inc.".
# Company already in cache. Skipping.
# Geocoding company "S.J.H Trucking Services Inc".
# Company already in cache. Skipping.
# Geocoding company "S.K. Davison, Inc.".
# Company already in cache. Skipping.
# Geocoding company "S.M.S. Construction, Inc.".
# Company already in cache. Skipping.
# Geocoding company "S2C Focus Inc".
# Company already in cache. Skipping.
# Geocoding company "S2O Consultants, Inc".
# Company already in cache. Skipping.
# Geocoding company "SAFE ZONE SERVICES LLC".
# Company already in cache. Skipping.
# Geocoding company "SALAS TRUCKING INC.".
# Company already in cache. Skipping.
# Geocoding company "SAMS Transit LLC".
# Company already in cache. Skipping.
# Geocoding company "SANBRYTH LLC".
# Company already in cache. Skipping.
# Geocoding company "SARAY TRUCKING INC".
# Company already in cache. Skipping.
# Geocoding company "SAVVY Technology Solutions LLC".
# Company already in cache. Skipping.
# Geocoding company "SBC WASTE SOLUTIONS INC".
# Company already in cache. Skipping.
# Geocoding company "SBE Media Consulting, LLC".
# Company already in cache. Skipping.
# Geocoding company "SC-B Consulting Incorporated".
# Company already in cache. Skipping.
# Geocoding company "SCB Management Solutions, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Saavedra Group Architects".
# Company already in cache. Skipping.
# Geocoding company "Sabur Surveying, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Sachi Construction, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Safe Circle Transportation Co.".
# Company already in cache. Skipping.
# Geocoding company "Safe Couriers Inc.".
# Company already in cache. Skipping.
# Geocoding company "Safe Journey 4U LLC".
# Company already in cache. Skipping.
# Geocoding company "Safe-Guard Security and Investigation Corporation".
# Company already in cache. Skipping.
# Geocoding company "Safety Quality Service, LLC.".
# Company already in cache. Skipping.
# Geocoding company "Safety Resources, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Safety Supply Illinois LLC".
# Company already in cache. Skipping.
# Geocoding company "Safeway Construction Company, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Sage Health Strategy Inc.".
# Company already in cache. Skipping.
# Geocoding company "SageTech Solutions, Inc".
# Company already in cache. Skipping.
# Geocoding company "Saiful/Bouquet Consulting Structural Engineers, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Saigon Sisters, LLC".
# Company already in cache. Skipping.
# Geocoding company "Saint Louis Antique Lighting Company, Inc".
# Company already in cache. Skipping.
# Geocoding company "Sakayan Inc.".
# Company already in cache. Skipping.
# Geocoding company "Salamanca& Meza LLC".
# Company already in cache. Skipping.
# Geocoding company "Salas Trucking Inc.".
# Company already in cache. Skipping.
# Geocoding company "Saldemar Solutions, LLC".
# Company already in cache. Skipping.
# Geocoding company "Salina & Associates, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Salomon's Trucking, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Samana Group, LLC".
# Company already in cache. Skipping.
# Geocoding company "Samara Woodcraft and Design LLC".
# Company already in cache. Skipping.
# Geocoding company "Samayoa's Transportation Inc.,".
# Company already in cache. Skipping.
# Geocoding company "Samperio Trucking Inc.".
# Company already in cache. Skipping.
# Geocoding company "Sanchez & Associates, P.C.".
# Company already in cache. Skipping.
# Geocoding company "Sanchez Daniels & Hoffman LLP".
# Company already in cache. Skipping.
# Geocoding company "Sanchez Paving Company".
# Company already in cache. Skipping.
# Geocoding company "Sanders Landscaping, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Sandi Llano & Associates Inc".
# Company already in cache. Skipping.
# Geocoding company "Sandoval Fences Corp.".
# Company already in cache. Skipping.
# Geocoding company "Sandsmith Masonry, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Sansa Solutions LLC".
# Company already in cache. Skipping.
# Geocoding company "Santa Klorina LLC".
# Company already in cache. Skipping.
# Geocoding company "Santacruz Associates, Ltd.".
# Company already in cache. Skipping.
# Geocoding company "Santos McLeese, LLC".
# Company already in cache. Skipping.
# Geocoding company "Sanveo, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Saquan Gholar dba Rescue 8 Special Events & Training Inc.".
# Company already in cache. Skipping.
# Geocoding company "Saris and Things, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Sath Inc.".
# Company already in cache. Skipping.
# Geocoding company "Savan Source Inc.".
# Company already in cache. Skipping.
# Geocoding company "Savory Crust, LLC".
# Company already in cache. Skipping.
# Geocoding company "Scacco, LLC".
# Company already in cache. Skipping.
# Geocoding company "Scale Construction Inc.".
# Company already in cache. Skipping.
# Geocoding company "Scanlon Excavating and Concrete, Inc.".
# Company already in cache. Skipping.
# Geocoding company "Scarfe Consulting LLC".
# Company already in cache. Skipping.
# Geocoding company "Scarlet Construction Inc".
# Company already in cache. Skipping.
# Geocoding company "Scepter Group LLC".
# Company already in cache. Skipping.
# Geocoding company "Schatz Services, LLC".
# Company already in cache. Skipping.
# Geocoding company "Schierbaum Excavating, Inc.".
# Company already in cache. Skipping.
# Geocoding company "The Paniagua Group, Incorporated".
# Company already in cache. Skipping.
# Geocoding company "a1a Design Group Corporation".
# Company already in cache. Skipping.
# Geocoding company "asaya Design".
# Company already in cache. Skipping.
# Geocoding company "baso Ltd.".
# Company already in cache. Skipping.
# Geocoding company "byjean & company".
# Company already in cache. Skipping.
# Geocoding company "d'Escoto, Inc.".
# Company already in cache. Skipping.
# Geocoding company "eBizUniverse, Inc.".
# Company already in cache. Skipping.
# Geocoding company "eComply Solutions, LLC".
# Company already in cache. Skipping.
# Geocoding company "eSense Incorporated".
# Company already in cache. Skipping.
# Geocoding company "eTek IT Services, Inc.".
# Company already in cache. Skipping.
# Geocoding company "edCount, LLC".
# Company already in cache. Skipping.
# Geocoding company "ef - Design Group, Inc.".
# Company already in cache. Skipping.
# Geocoding company "iBusiness Solution LLC".
# Company already in cache. Skipping.
# Geocoding company "iLink Resources, Inc.".
# Company already in cache. Skipping.
# Geocoding company "iManage Enterprises INC".
# Company already in cache. Skipping.
# Geocoding company "iPropertyManage inc".
# Company already in cache. Skipping.
# Geocoding company "iSource Solutions Inc".
# Company already in cache. Skipping.
# Geocoding company "innovation landscape, Inc".
# Company already in cache. Skipping.
# Geocoding company "j guerrero trucking and paving inc.".
# Company already in cache. Skipping.
# Geocoding company "j. st. jaimes".
# Company already in cache. Skipping.
# Geocoding company "jimmy williams gallery and studio LLC".
# Company already in cache. Skipping.
# Geocoding company "kci Enterprises, Inc.".
# Company already in cache. Skipping.
# Geocoding company "legacy coatings, inc".
# Company already in cache. Skipping.
# Geocoding company "legacy rail operations, LLC".
# Company already in cache. Skipping.
# Geocoding company "mk communications".
# Company already in cache. Skipping.
# Geocoding company "myWHY Agency, Inc.".
# Company already in cache. Skipping.
# Geocoding company "netlogx LLC".
# Company already in cache. Skipping.
# Geocoding company "r6catalyst, LLC".
# Company already in cache. Skipping.
# Geocoding company "rSTAR Technologies, LLC".
# Company already in cache. Skipping.
# Geocoding complete.

# %%
# Create new DataFrame from geocoded addresses
geocoded_df = (pd
    .DataFrame
    .from_dict(cache, orient="index")
    .reset_index()
    .rename(columns={"index": "Company Name"}))

# Merge geocoded addresses to company names
geocoded_companies_df = physical_address_df[['Company Name']].merge(
    right=geocoded_df,
    how="left",
    on="Company Name")

# Preview DataFrame
geocoded_companies_df
# Out:
#                                   Company Name   Latitude  Longitude  \
# 0            #1 Professional Cleaning Services  41.848017 -87.891201
# 1                               #9 Design, LLC  41.890007 -87.992682
# 2                     'Bouche' Enterprises LLC  41.943783 -87.812819
# 3     'Merica Made Painting & Decorating Corp.  41.779011 -87.771186
# 4                       *VDR Development Group  41.931275 -88.083132
# ...                                        ...        ...        ...
# 4972                         mk communications  41.890224 -87.637564
# 4973                        myWHY Agency, Inc.  41.777845 -87.601262
# 4974                               netlogx LLC  39.772103 -86.149574
# 4975                           r6catalyst, LLC  39.872830 -74.811213
# 4976                   rSTAR Technologies, LLC  41.814510 -87.953362
#
#                       Street              City             County State  \
# 0           2205 Mayfair Ave       Westchester        Cook County    IL
# 1     524 W Saint Charles Rd        Villa Park      DuPage County    IL
# 2         3511 N Osceola Ave           Chicago        Cook County    IL
# 3          6221 S Austin Ave           Chicago        Cook County    IL
# 4           168 N Brandon Dr  Glendale Heights      DuPage County    IL
# ...                      ...               ...                ...   ...
# 4972        350 W Hubbard St           Chicago        Cook County    IL
# 4973    6425 S Ingleside Ave           Chicago        Cook County    IL
# 4974        429 E Vermont St      Indianapolis      Marion County    IN
# 4975           617 Stokes Rd           Medford  Burlington County    NJ
# 4976      770 Pasquinelli Dr          Westmont      DuPage County    IL
#
#      Confidence
# 0          High
# 1          High
# 2          High
# 3          High
# 4          High
# ...         ...
# 4972       High
# 4973       High
# 4974       High
# 4975       High
# 4976       High
#
# [4977 rows x 8 columns]

# %%
# Define column for full street address
physical_address_df['Original Address'] = physical_address_df["Street"].apply(lambda s: s.replace(".", "")) + \
    ", " + physical_address_df["City"] + ", " + \
    physical_address_df["State"]

# Merge column to geocoded addresses as "Original Address"
geocoded_companies_df = geocoded_companies_df.merge(
    right=physical_address_df[['Company Name', 'Original Address']],
    how="left",
    on="Company Name")

geocoded_companies_df.head()
# Out:
#                                Company Name   Latitude  Longitude  \
# 0         #1 Professional Cleaning Services  41.848017 -87.891201
# 1                            #9 Design, LLC  41.890007 -87.992682
# 2                  'Bouche' Enterprises LLC  41.943783 -87.812819
# 3  'Merica Made Painting & Decorating Corp.  41.779011 -87.771186
# 4                    *VDR Development Group  41.931275 -88.083132
#
#                    Street              City         County State Confidence  \
# 0        2205 Mayfair Ave       Westchester    Cook County    IL       High
# 1  524 W Saint Charles Rd        Villa Park  DuPage County    IL       High
# 2      3511 N Osceola Ave           Chicago    Cook County    IL       High
# 3       6221 S Austin Ave           Chicago    Cook County    IL       High
# 4        168 N Brandon Dr  Glendale Heights  DuPage County    IL       High
#
#                               Original Address
# 0                2205 Mayfair, Westchester, IL
# 1  524 West Saint Charles Road, Villa Park, IL
# 2       3511 North Osceola Avenue, Chicago, IL
# 3               6221 S Austin Ave, Chicago, IL
# 4    168 N Brandon Drive, Glendale Heights, IL

# %%
# Get original addresses of companies that may have been skipped during
# the geocoding process because they shared the same address with another entry
failures = geocoded_companies_df.query("Latitude != Latitude")['Original Address'].tolist()
ref_df = geocoded_companies_df.query("`Original Address` in @failures").groupby('Original Address').first().reset_index()

# Define local function to correct skipped companies
def fix_failures(row: pd.Series):
    original_addr = row['Original Address'] 
    if original_addr in failures:
        ref = ref_df.query("`Original Address` == @original_addr").iloc[0]
        return [
            row['Company Name'],
            ref['Latitude'],
            ref['Longitude'],
            ref['Street'],
            ref['City'],
            ref['County'],
            ref['State'],
            ref['Confidence'],
            original_addr
        ]

    else:
        return row

# Apply function across DataFrame
fixed_geocoded = geocoded_companies_df.apply(fix_failures, axis="columns", result_type='broadcast')

# Determine what rows are still not successfully geocoded, if any
# TODO: Address these entries manually or with a Python package
# that performs address normalization
fixed_geocoded.query("Latitude != Latitude")
# Out:
#                                            Company Name Latitude Longitude  \
# 883                                    Blue Timber, LLC      NaN       NaN
# 1398  Combined Card Services, Inc. D/b/a Viva's Hall...      NaN       NaN
# 1727             Delivery & Distribution Solutions, LLC      NaN       NaN
# 2004                         EmeraldAI Technologies LLC      NaN       NaN
# 2351                         Galaxy Environmental, Inc.      NaN       NaN
# 2682                                    HireLevel, Inc.      NaN       NaN
# 3315                                   LAW Realty, Ltd.      NaN       NaN
# 3316                                 LAW Ventures, Ltd.      NaN       NaN
# 3808                                   Mega Steel Corp.      NaN       NaN
# 4559                                        QU-BAR, INC      NaN       NaN
# 4707                            Raptor Industries, Inc.      NaN       NaN
#
#      Street  City County State Confidence  \
# 883    None  None   None  None       None
# 1398   None  None   None  None       None
# 1727   None  None   None  None       None
# 2004   None  None   None  None       None
# 2351   None  None   None  None       None
# 2682   None  None   None  None       None
# 3315   None  None   None  None       None
# 3316   None  None   None  None       None
# 3808   None  None   None  None       None
# 4559   None  None   None  None       None
# 4707   None  None   None  None       None
#
#                                        Original Address
# 883   60 W Terra Cotta Ave Ste: B 163, Crystal Lake, IL
# 1398                    5757 S Cicero Ave,, Chicago, IL
# 1727  16W 251 S Frontage Rd, Unit 21 & 22, Burr Ridg...
# 2004  4 Cortland Cir, Attn: Susan Stellflue, Lake Zu...
# 2351  3565 N Milwaukee Ave, Attn: George Salinas, Ch...
# 2682      3016 Locust St Suite 102 & 103, St. Louis, MO
# 3315  2404 S Wolcott Ave, Unit 21 Suite: 1A & B, Chi...
# 3316  2404 S Wolcott Unit 21 Suite 1 A & B, Chicago, IL
# 3808  556 County Line Road, Suite D, Attn: Arlene Ba...
# 4559            4163 A&B W 166th Street, Oak Forest, IL
# 4707                1602 N Park Dr,, Mount Prospect, IL

# %%
# Write DataFrame to storage
fixed_geocoded.to_csv("../data/clean/bep_company_addresses_physical_geocoded.csv", index=False)
