# %% [markdown]
# ### State demographics and business-related data

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../codes/')

# %%
import utils
import utils.cleaning, utils.geocoding, utils.vizualizing

# %%
census = pd.read_csv("../data/raw/IL_census_data.csv")
business = pd.read_csv("../data/raw/IL_business_data.csv")
bounds = gpd.read_file("../data/raw/IL_BNDY_County_Py.shp")

# %%
cleaned_data = cleaning.merge_geo(census, business, bounds)

# %%
vizualizing.plotting(cleaned_data)
